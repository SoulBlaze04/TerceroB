# %% [markdown]
# # Percepción (PER): examen de prácticas del bloque 2, grupo 3CO11, turno1, 28-5-2024, 8:00-8:45
#
# Lee este cuaderno y realiza las actividades y ejercicios propuestos

# %% [markdown]
# ## Importación de librerías relevantes

# %%
import warnings; warnings.filterwarnings("ignore")
import numpy as np
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.decomposition import PCA
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier, HistGradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
from sklearn.metrics import accuracy_score

def parse_dni(x):
    return x % 1000

# %% [markdown]
# ## Lectura y partición del corpus eye-movements
#
# Ejecuta el código siguiente con dni igual a tu DNI/NIE sin letra.

# %%
dni = 23325581

X, y = fetch_openml("eye_movements", version=9, return_X_y=True, as_frame=False)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.1, shuffle=True, random_state=parse_dni(dni))

print(f'N = {X.shape[0]} D = {X.shape[1]} C = {len(np.unique(y))} N_train = {len(X_train)} N_test = {len(X_test)}')
# Out:
# N = 7608 D = 23 C = 2 N_train = 6847 N_test = 761

# %% [markdown]
# Tarea del [**tabular data learning benchmark**](https://arxiv.org/abs/2207.08815) basada en la competición 1 del [eyechallenge2005](http://www.cis.hut.fi/eyechallenge2005). Se trata de predecir la relevancia o no de una frase leída en un documento (2 clases) a partir de la trayectoria de movimientos oculares asociada (22 características).

# %% [markdown]
# ## Experimento de referencia con GradientBoosting
#
# Ejecuta el código siguiente para estudiar el error de GradientBoosting con parámetros por defecto.

# %%
clf = GradientBoostingClassifier(random_state=parse_dni(dni))

acc = clf.fit(X_train[:1000], y_train[:1000]).score(X_test, y_test)
print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 57.7%

# %% [markdown]
# ## Ejercicio 1
#
# Modifica el código de referencia para estudiar el error de GradientBoosting con ajuste de hiper-parámetros mediante alguna de las técnicas de optimización explicadas en las prácticas.

# %%
# %%timeit -n1 -r1

from sklearn.model_selection import GridSearchCV

G = {"max_depth": [1,2,3,5,10],"n_estimators":[10,20,50,100,150,200],"max_features":[10,20,30,40,57]}

GS = GridSearchCV(clf, G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 150 candidates, totalling 750 fits
# [CV 1/5; 1/150] START max_depth=1, max_features=10, n_estimators=10.............
# [CV 1/5; 1/150] END max_depth=1, max_features=10, n_estimators=10;, score=0.548 total time=   0.0s
# [CV 2/5; 1/150] START max_depth=1, max_features=10, n_estimators=10.............
# [CV 2/5; 1/150] END max_depth=1, max_features=10, n_estimators=10;, score=0.546 total time=   0.0s
# [CV 3/5; 1/150] START max_depth=1, max_features=10, n_estimators=10.............
# [CV 3/5; 1/150] END max_depth=1, max_features=10, n_estimators=10;, score=0.554 total time=   0.0s
# [CV 4/5; 1/150] START max_depth=1, max_features=10, n_estimators=10.............
# [CV 4/5; 1/150] END max_depth=1, max_features=10, n_estimators=10;, score=0.572 total time=   0.0s
# [CV 5/5; 1/150] START max_depth=1, max_features=10, n_estimators=10.............
# [CV 5/5; 1/150] END max_depth=1, max_features=10, n_estimators=10;, score=0.573 total time=   0.0s
# [CV 1/5; 2/150] START max_depth=1, max_features=10, n_estimators=20.............
# [CV 1/5; 2/150] END max_depth=1, max_features=10, n_estimators=20;, score=0.572 total time=   0.1s
# [CV 2/5; 2/150] START max_depth=1, max_features=10, n_estimators=20.............
# [CV 2/5; 2/150] END max_depth=1, max_features=10, n_estimators=20;, score=0.577 total time=   0.1s
# [CV 3/5; 2/150] START max_depth=1, max_features=10, n_estimators=20.............
# [CV 3/5; 2/150] END max_depth=1, max_features=10, n_estimators=20;, score=0.575 total time=   0.1s
# [CV 4/5; 2/150] START max_depth=1, max_features=10, n_estimators=20.............
# [CV 4/5; 2/150] END max_depth=1, max_features=10, n_estimators=20;, score=0.569 total time=   0.0s
# [CV 5/5; 2/150] START max_depth=1, max_features=10, n_estimators=20.............
# [CV 5/5; 2/150] END max_depth=1, max_features=10, n_estimators=20;, score=0.581 total time=   0.1s
# [CV 1/5; 3/150] START max_depth=1, max_features=10, n_estimators=50.............
# [CV 1/5; 3/150] END max_depth=1, max_features=10, n_estimators=50;, score=0.574 total time=   0.3s
# [CV 2/5; 3/150] START max_depth=1, max_features=10, n_estimators=50.............
# [CV 2/5; 3/150] END max_depth=1, max_features=10, n_estimators=50;, score=0.579 total time=   0.4s
# [CV 3/5; 3/150] START max_depth=1, max_features=10, n_estimators=50.............
# [CV 3/5; 3/150] END max_depth=1, max_features=10, n_estimators=50;, score=0.579 total time=   0.3s
# [CV 4/5; 3/150] START max_depth=1, max_features=10, n_estimators=50.............
# [CV 4/5; 3/150] END max_depth=1, max_features=10, n_estimators=50;, score=0.582 total time=   0.3s
# [CV 5/5; 3/150] START max_depth=1, max_features=10, n_estimators=50.............
# [CV 5/5; 3/150] END max_depth=1, max_features=10, n_estimators=50;, score=0.590 total time=   0.3s
# [CV 1/5; 4/150] START max_depth=1, max_features=10, n_estimators=100............
# [CV 1/5; 4/150] END max_depth=1, max_features=10, n_estimators=100;, score=0.593 total time=   0.7s
# [CV 2/5; 4/150] START max_depth=1, max_features=10, n_estimators=100............
# [CV 2/5; 4/150] END max_depth=1, max_features=10, n_estimators=100;, score=0.578 total time=   0.7s
# [CV 3/5; 4/150] START max_depth=1, max_features=10, n_estimators=100............
# [CV 3/5; 4/150] END max_depth=1, max_features=10, n_estimators=100;, score=0.581 total time=   0.6s
# [CV 4/5; 4/150] START max_depth=1, max_features=10, n_estimators=100............
# [CV 4/5; 4/150] END max_depth=1, max_features=10, n_estimators=100;, score=0.592 total time=   0.7s
# [CV 5/5; 4/150] START max_depth=1, max_features=10, n_estimators=100............
# [CV 5/5; 4/150] END max_depth=1, max_features=10, n_estimators=100;, score=0.600 total time=   0.8s
# [CV 1/5; 5/150] START max_depth=1, max_features=10, n_estimators=150............
# [CV 1/5; 5/150] END max_depth=1, max_features=10, n_estimators=150;, score=0.596 total time=   1.1s
# [CV 2/5; 5/150] START max_depth=1, max_features=10, n_estimators=150............
# [CV 2/5; 5/150] END max_depth=1, max_features=10, n_estimators=150;, score=0.580 total time=   1.0s
# [CV 3/5; 5/150] START max_depth=1, max_features=10, n_estimators=150............
# [CV 3/5; 5/150] END max_depth=1, max_features=10, n_estimators=150;, score=0.586 total time=   0.9s
# [CV 4/5; 5/150] START max_depth=1, max_features=10, n_estimators=150............
# [CV 4/5; 5/150] END max_depth=1, max_features=10, n_estimators=150;, score=0.589 total time=   1.0s
# [CV 5/5; 5/150] START max_depth=1, max_features=10, n_estimators=150............
# [CV 5/5; 5/150] END max_depth=1, max_features=10, n_estimators=150;, score=0.589 total time=   0.9s
# [CV 1/5; 6/150] START max_depth=1, max_features=10, n_estimators=200............
# [CV 1/5; 6/150] END max_depth=1, max_features=10, n_estimators=200;, score=0.594 total time=   1.3s
# [CV 2/5; 6/150] START max_depth=1, max_features=10, n_estimators=200............
# [CV 2/5; 6/150] END max_depth=1, max_features=10, n_estimators=200;, score=0.572 total time=   1.5s
# [CV 3/5; 6/150] START max_depth=1, max_features=10, n_estimators=200............
# [CV 3/5; 6/150] END max_depth=1, max_features=10, n_estimators=200;, score=0.585 total time=   1.3s
# [CV 4/5; 6/150] START max_depth=1, max_features=10, n_estimators=200............
# [CV 4/5; 6/150] END max_depth=1, max_features=10, n_estimators=200;, score=0.595 total time=   1.4s
# [CV 5/5; 6/150] START max_depth=1, max_features=10, n_estimators=200............
# [CV 5/5; 6/150] END max_depth=1, max_features=10, n_estimators=200;, score=0.597 total time=   1.2s
# [CV 1/5; 7/150] START max_depth=1, max_features=20, n_estimators=10.............
# [CV 1/5; 7/150] END max_depth=1, max_features=20, n_estimators=10;, score=0.566 total time=   0.0s
# [CV 2/5; 7/150] START max_depth=1, max_features=20, n_estimators=10.............
# [CV 2/5; 7/150] END max_depth=1, max_features=20, n_estimators=10;, score=0.546 total time=   0.0s
# [CV 3/5; 7/150] START max_depth=1, max_features=20, n_estimators=10.............
# [CV 3/5; 7/150] END max_depth=1, max_features=20, n_estimators=10;, score=0.554 total time=   0.0s
# [CV 4/5; 7/150] START max_depth=1, max_features=20, n_estimators=10.............
# [CV 4/5; 7/150] END max_depth=1, max_features=20, n_estimators=10;, score=0.572 total time=   0.0s
# [CV 5/5; 7/150] START max_depth=1, max_features=20, n_estimators=10.............
# [CV 5/5; 7/150] END max_depth=1, max_features=20, n_estimators=10;, score=0.562 total time=   0.0s
# [CV 1/5; 8/150] START max_depth=1, max_features=20, n_estimators=20.............
# [CV 1/5; 8/150] END max_depth=1, max_features=20, n_estimators=20;, score=0.572 total time=   0.2s
# [CV 2/5; 8/150] START max_depth=1, max_features=20, n_estimators=20.............
# [CV 2/5; 8/150] END max_depth=1, max_features=20, n_estimators=20;, score=0.577 total time=   0.2s
# [CV 3/5; 8/150] START max_depth=1, max_features=20, n_estimators=20.............
# [CV 3/5; 8/150] END max_depth=1, max_features=20, n_estimators=20;, score=0.576 total time=   0.2s
# [CV 4/5; 8/150] START max_depth=1, max_features=20, n_estimators=20.............
# [CV 4/5; 8/150] END max_depth=1, max_features=20, n_estimators=20;, score=0.574 total time=   0.2s
# [CV 5/5; 8/150] START max_depth=1, max_features=20, n_estimators=20.............
# [CV 5/5; 8/150] END max_depth=1, max_features=20, n_estimators=20;, score=0.573 total time=   0.2s
# [CV 1/5; 9/150] START max_depth=1, max_features=20, n_estimators=50.............
# [CV 1/5; 9/150] END max_depth=1, max_features=20, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 2/5; 9/150] START max_depth=1, max_features=20, n_estimators=50.............
# [CV 2/5; 9/150] END max_depth=1, max_features=20, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 3/5; 9/150] START max_depth=1, max_features=20, n_estimators=50.............
# [CV 3/5; 9/150] END max_depth=1, max_features=20, n_estimators=50;, score=0.581 total time=   0.5s
# [CV 4/5; 9/150] START max_depth=1, max_features=20, n_estimators=50.............
# [CV 4/5; 9/150] END max_depth=1, max_features=20, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 5/5; 9/150] START max_depth=1, max_features=20, n_estimators=50.............
# [CV 5/5; 9/150] END max_depth=1, max_features=20, n_estimators=50;, score=0.589 total time=   0.5s
# [CV 1/5; 10/150] START max_depth=1, max_features=20, n_estimators=100...........
# [CV 1/5; 10/150] END max_depth=1, max_features=20, n_estimators=100;, score=0.586 total time=   1.3s
# [CV 2/5; 10/150] START max_depth=1, max_features=20, n_estimators=100...........
# [CV 2/5; 10/150] END max_depth=1, max_features=20, n_estimators=100;, score=0.577 total time=   1.4s
# [CV 3/5; 10/150] START max_depth=1, max_features=20, n_estimators=100...........
# [CV 3/5; 10/150] END max_depth=1, max_features=20, n_estimators=100;, score=0.581 total time=   1.3s
# [CV 4/5; 10/150] START max_depth=1, max_features=20, n_estimators=100...........
# [CV 4/5; 10/150] END max_depth=1, max_features=20, n_estimators=100;, score=0.589 total time=   1.3s
# [CV 5/5; 10/150] START max_depth=1, max_features=20, n_estimators=100...........
# [CV 5/5; 10/150] END max_depth=1, max_features=20, n_estimators=100;, score=0.602 total time=   1.1s
# [CV 1/5; 11/150] START max_depth=1, max_features=20, n_estimators=150...........
# [CV 1/5; 11/150] END max_depth=1, max_features=20, n_estimators=150;, score=0.598 total time=   1.9s
# [CV 2/5; 11/150] START max_depth=1, max_features=20, n_estimators=150...........
# [CV 2/5; 11/150] END max_depth=1, max_features=20, n_estimators=150;, score=0.580 total time=   1.8s
# [CV 3/5; 11/150] START max_depth=1, max_features=20, n_estimators=150...........
# [CV 3/5; 11/150] END max_depth=1, max_features=20, n_estimators=150;, score=0.585 total time=   1.9s
# [CV 4/5; 11/150] START max_depth=1, max_features=20, n_estimators=150...........
# [CV 4/5; 11/150] END max_depth=1, max_features=20, n_estimators=150;, score=0.587 total time=   1.8s
# [CV 5/5; 11/150] START max_depth=1, max_features=20, n_estimators=150...........
# [CV 5/5; 11/150] END max_depth=1, max_features=20, n_estimators=150;, score=0.595 total time=   2.2s
# [CV 1/5; 12/150] START max_depth=1, max_features=20, n_estimators=200...........
# [CV 1/5; 12/150] END max_depth=1, max_features=20, n_estimators=200;, score=0.593 total time=   2.5s
# [CV 2/5; 12/150] START max_depth=1, max_features=20, n_estimators=200...........
# [CV 2/5; 12/150] END max_depth=1, max_features=20, n_estimators=200;, score=0.574 total time=   2.7s
# [CV 3/5; 12/150] START max_depth=1, max_features=20, n_estimators=200...........
# [CV 3/5; 12/150] END max_depth=1, max_features=20, n_estimators=200;, score=0.584 total time=   2.4s
# [CV 4/5; 12/150] START max_depth=1, max_features=20, n_estimators=200...........
# [CV 4/5; 12/150] END max_depth=1, max_features=20, n_estimators=200;, score=0.595 total time=   2.6s
# [CV 5/5; 12/150] START max_depth=1, max_features=20, n_estimators=200...........
# [CV 5/5; 12/150] END max_depth=1, max_features=20, n_estimators=200;, score=0.597 total time=   2.3s
# [CV 1/5; 13/150] START max_depth=1, max_features=30, n_estimators=10............
# [CV 1/5; 13/150] END max_depth=1, max_features=30, n_estimators=10;, score=0.566 total time=   0.1s
# [CV 2/5; 13/150] START max_depth=1, max_features=30, n_estimators=10............
# [CV 2/5; 13/150] END max_depth=1, max_features=30, n_estimators=10;, score=0.546 total time=   0.1s
# [CV 3/5; 13/150] START max_depth=1, max_features=30, n_estimators=10............
# [CV 3/5; 13/150] END max_depth=1, max_features=30, n_estimators=10;, score=0.554 total time=   0.1s
# [CV 4/5; 13/150] START max_depth=1, max_features=30, n_estimators=10............
# [CV 4/5; 13/150] END max_depth=1, max_features=30, n_estimators=10;, score=0.572 total time=   0.1s
# [CV 5/5; 13/150] START max_depth=1, max_features=30, n_estimators=10............
# [CV 5/5; 13/150] END max_depth=1, max_features=30, n_estimators=10;, score=0.562 total time=   0.1s
# [CV 1/5; 14/150] START max_depth=1, max_features=30, n_estimators=20............
# [CV 1/5; 14/150] END max_depth=1, max_features=30, n_estimators=20;, score=0.572 total time=   0.2s
# [CV 2/5; 14/150] START max_depth=1, max_features=30, n_estimators=20............
# [CV 2/5; 14/150] END max_depth=1, max_features=30, n_estimators=20;, score=0.577 total time=   0.2s
# [CV 3/5; 14/150] START max_depth=1, max_features=30, n_estimators=20............
# [CV 3/5; 14/150] END max_depth=1, max_features=30, n_estimators=20;, score=0.576 total time=   0.2s
# [CV 4/5; 14/150] START max_depth=1, max_features=30, n_estimators=20............
# [CV 4/5; 14/150] END max_depth=1, max_features=30, n_estimators=20;, score=0.574 total time=   0.2s
# [CV 5/5; 14/150] START max_depth=1, max_features=30, n_estimators=20............
# [CV 5/5; 14/150] END max_depth=1, max_features=30, n_estimators=20;, score=0.573 total time=   0.2s
# [CV 1/5; 15/150] START max_depth=1, max_features=30, n_estimators=50............
# [CV 1/5; 15/150] END max_depth=1, max_features=30, n_estimators=50;, score=0.577 total time=   0.7s
# [CV 2/5; 15/150] START max_depth=1, max_features=30, n_estimators=50............
# [CV 2/5; 15/150] END max_depth=1, max_features=30, n_estimators=50;, score=0.580 total time=   0.7s
# [CV 3/5; 15/150] START max_depth=1, max_features=30, n_estimators=50............
# [CV 3/5; 15/150] END max_depth=1, max_features=30, n_estimators=50;, score=0.585 total time=   0.6s
# [CV 4/5; 15/150] START max_depth=1, max_features=30, n_estimators=50............
# [CV 4/5; 15/150] END max_depth=1, max_features=30, n_estimators=50;, score=0.578 total time=   0.7s
# [CV 5/5; 15/150] START max_depth=1, max_features=30, n_estimators=50............
# [CV 5/5; 15/150] END max_depth=1, max_features=30, n_estimators=50;, score=0.589 total time=   0.6s
# [CV 1/5; 16/150] START max_depth=1, max_features=30, n_estimators=100...........
# [CV 1/5; 16/150] END max_depth=1, max_features=30, n_estimators=100;, score=0.587 total time=   1.3s
# [CV 2/5; 16/150] START max_depth=1, max_features=30, n_estimators=100...........
# [CV 2/5; 16/150] END max_depth=1, max_features=30, n_estimators=100;, score=0.578 total time=   1.5s
# [CV 3/5; 16/150] START max_depth=1, max_features=30, n_estimators=100...........
# [CV 3/5; 16/150] END max_depth=1, max_features=30, n_estimators=100;, score=0.583 total time=   1.3s
# [CV 4/5; 16/150] START max_depth=1, max_features=30, n_estimators=100...........
# [CV 4/5; 16/150] END max_depth=1, max_features=30, n_estimators=100;, score=0.584 total time=   1.6s
# [CV 5/5; 16/150] START max_depth=1, max_features=30, n_estimators=100...........
# [CV 5/5; 16/150] END max_depth=1, max_features=30, n_estimators=100;, score=0.601 total time=   1.4s
# [CV 1/5; 17/150] START max_depth=1, max_features=30, n_estimators=150...........
# [CV 1/5; 17/150] END max_depth=1, max_features=30, n_estimators=150;, score=0.594 total time=   2.1s
# [CV 2/5; 17/150] START max_depth=1, max_features=30, n_estimators=150...........
# [CV 2/5; 17/150] END max_depth=1, max_features=30, n_estimators=150;, score=0.577 total time=   2.2s
# [CV 3/5; 17/150] START max_depth=1, max_features=30, n_estimators=150...........
# [CV 3/5; 17/150] END max_depth=1, max_features=30, n_estimators=150;, score=0.587 total time=   2.4s
# [CV 4/5; 17/150] START max_depth=1, max_features=30, n_estimators=150...........
# [CV 4/5; 17/150] END max_depth=1, max_features=30, n_estimators=150;, score=0.592 total time=   2.6s
# [CV 5/5; 17/150] START max_depth=1, max_features=30, n_estimators=150...........
# [CV 5/5; 17/150] END max_depth=1, max_features=30, n_estimators=150;, score=0.595 total time=   2.4s
# [CV 1/5; 18/150] START max_depth=1, max_features=30, n_estimators=200...........
# [CV 1/5; 18/150] END max_depth=1, max_features=30, n_estimators=200;, score=0.594 total time=   2.7s
# [CV 2/5; 18/150] START max_depth=1, max_features=30, n_estimators=200...........
# [CV 2/5; 18/150] END max_depth=1, max_features=30, n_estimators=200;, score=0.570 total time=   3.0s
# [CV 3/5; 18/150] START max_depth=1, max_features=30, n_estimators=200...........
# [CV 3/5; 18/150] END max_depth=1, max_features=30, n_estimators=200;, score=0.585 total time=   2.6s
# [CV 4/5; 18/150] START max_depth=1, max_features=30, n_estimators=200...........
# [CV 4/5; 18/150] END max_depth=1, max_features=30, n_estimators=200;, score=0.595 total time=   2.8s
# [CV 5/5; 18/150] START max_depth=1, max_features=30, n_estimators=200...........
# [CV 5/5; 18/150] END max_depth=1, max_features=30, n_estimators=200;, score=0.597 total time=   3.1s
# [CV 1/5; 19/150] START max_depth=1, max_features=40, n_estimators=10............
# [CV 1/5; 19/150] END max_depth=1, max_features=40, n_estimators=10;, score=0.566 total time=   0.1s
# [CV 2/5; 19/150] START max_depth=1, max_features=40, n_estimators=10............
# [CV 2/5; 19/150] END max_depth=1, max_features=40, n_estimators=10;, score=0.546 total time=   0.0s
# [CV 3/5; 19/150] START max_depth=1, max_features=40, n_estimators=10............
# [CV 3/5; 19/150] END max_depth=1, max_features=40, n_estimators=10;, score=0.554 total time=   0.1s
# [CV 4/5; 19/150] START max_depth=1, max_features=40, n_estimators=10............
# [CV 4/5; 19/150] END max_depth=1, max_features=40, n_estimators=10;, score=0.572 total time=   0.0s
# [CV 5/5; 19/150] START max_depth=1, max_features=40, n_estimators=10............
# [CV 5/5; 19/150] END max_depth=1, max_features=40, n_estimators=10;, score=0.562 total time=   0.1s
# [CV 1/5; 20/150] START max_depth=1, max_features=40, n_estimators=20............
# [CV 1/5; 20/150] END max_depth=1, max_features=40, n_estimators=20;, score=0.572 total time=   0.2s
# [CV 2/5; 20/150] START max_depth=1, max_features=40, n_estimators=20............
# [CV 2/5; 20/150] END max_depth=1, max_features=40, n_estimators=20;, score=0.577 total time=   0.2s
# [CV 3/5; 20/150] START max_depth=1, max_features=40, n_estimators=20............
# [CV 3/5; 20/150] END max_depth=1, max_features=40, n_estimators=20;, score=0.576 total time=   0.2s
# [CV 4/5; 20/150] START max_depth=1, max_features=40, n_estimators=20............
# [CV 4/5; 20/150] END max_depth=1, max_features=40, n_estimators=20;, score=0.574 total time=   0.2s
# [CV 5/5; 20/150] START max_depth=1, max_features=40, n_estimators=20............
# [CV 5/5; 20/150] END max_depth=1, max_features=40, n_estimators=20;, score=0.573 total time=   0.2s
# [CV 1/5; 21/150] START max_depth=1, max_features=40, n_estimators=50............
# [CV 1/5; 21/150] END max_depth=1, max_features=40, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 2/5; 21/150] START max_depth=1, max_features=40, n_estimators=50............
# [CV 2/5; 21/150] END max_depth=1, max_features=40, n_estimators=50;, score=0.580 total time=   0.6s
# [CV 3/5; 21/150] START max_depth=1, max_features=40, n_estimators=50............
# [CV 3/5; 21/150] END max_depth=1, max_features=40, n_estimators=50;, score=0.585 total time=   0.6s
# [CV 4/5; 21/150] START max_depth=1, max_features=40, n_estimators=50............
# [CV 4/5; 21/150] END max_depth=1, max_features=40, n_estimators=50;, score=0.578 total time=   0.6s
# [CV 5/5; 21/150] START max_depth=1, max_features=40, n_estimators=50............
# [CV 5/5; 21/150] END max_depth=1, max_features=40, n_estimators=50;, score=0.589 total time=   0.7s
# [CV 1/5; 22/150] START max_depth=1, max_features=40, n_estimators=100...........
# [CV 1/5; 22/150] END max_depth=1, max_features=40, n_estimators=100;, score=0.587 total time=   1.3s
# [CV 2/5; 22/150] START max_depth=1, max_features=40, n_estimators=100...........
# [CV 2/5; 22/150] END max_depth=1, max_features=40, n_estimators=100;, score=0.578 total time=   1.5s
# [CV 3/5; 22/150] START max_depth=1, max_features=40, n_estimators=100...........
# [CV 3/5; 22/150] END max_depth=1, max_features=40, n_estimators=100;, score=0.583 total time=   1.6s
# [CV 4/5; 22/150] START max_depth=1, max_features=40, n_estimators=100...........
# [CV 4/5; 22/150] END max_depth=1, max_features=40, n_estimators=100;, score=0.584 total time=   1.6s
# [CV 5/5; 22/150] START max_depth=1, max_features=40, n_estimators=100...........
# [CV 5/5; 22/150] END max_depth=1, max_features=40, n_estimators=100;, score=0.601 total time=   1.7s
# [CV 1/5; 23/150] START max_depth=1, max_features=40, n_estimators=150...........
# [CV 1/5; 23/150] END max_depth=1, max_features=40, n_estimators=150;, score=0.594 total time=   2.1s
# [CV 2/5; 23/150] START max_depth=1, max_features=40, n_estimators=150...........
# [CV 2/5; 23/150] END max_depth=1, max_features=40, n_estimators=150;, score=0.577 total time=   2.1s
# [CV 3/5; 23/150] START max_depth=1, max_features=40, n_estimators=150...........
# [CV 3/5; 23/150] END max_depth=1, max_features=40, n_estimators=150;, score=0.587 total time=   1.9s
# [CV 4/5; 23/150] START max_depth=1, max_features=40, n_estimators=150...........
# [CV 4/5; 23/150] END max_depth=1, max_features=40, n_estimators=150;, score=0.592 total time=   2.2s
# [CV 5/5; 23/150] START max_depth=1, max_features=40, n_estimators=150...........
# [CV 5/5; 23/150] END max_depth=1, max_features=40, n_estimators=150;, score=0.595 total time=   2.1s
# [CV 1/5; 24/150] START max_depth=1, max_features=40, n_estimators=200...........
# [CV 1/5; 24/150] END max_depth=1, max_features=40, n_estimators=200;, score=0.594 total time=   2.7s
# [CV 2/5; 24/150] START max_depth=1, max_features=40, n_estimators=200...........
# [CV 2/5; 24/150] END max_depth=1, max_features=40, n_estimators=200;, score=0.570 total time=   2.9s
# [CV 3/5; 24/150] START max_depth=1, max_features=40, n_estimators=200...........
# [CV 3/5; 24/150] END max_depth=1, max_features=40, n_estimators=200;, score=0.585 total time=   2.7s
# [CV 4/5; 24/150] START max_depth=1, max_features=40, n_estimators=200...........
# [CV 4/5; 24/150] END max_depth=1, max_features=40, n_estimators=200;, score=0.595 total time=   2.7s
# [CV 5/5; 24/150] START max_depth=1, max_features=40, n_estimators=200...........
# [CV 5/5; 24/150] END max_depth=1, max_features=40, n_estimators=200;, score=0.597 total time=   3.0s
# [CV 1/5; 25/150] START max_depth=1, max_features=57, n_estimators=10............
# [CV 1/5; 25/150] END max_depth=1, max_features=57, n_estimators=10;, score=0.566 total time=   0.1s
# [CV 2/5; 25/150] START max_depth=1, max_features=57, n_estimators=10............
# [CV 2/5; 25/150] END max_depth=1, max_features=57, n_estimators=10;, score=0.546 total time=   0.0s
# [CV 3/5; 25/150] START max_depth=1, max_features=57, n_estimators=10............
# [CV 3/5; 25/150] END max_depth=1, max_features=57, n_estimators=10;, score=0.554 total time=   0.0s
# [CV 4/5; 25/150] START max_depth=1, max_features=57, n_estimators=10............
# [CV 4/5; 25/150] END max_depth=1, max_features=57, n_estimators=10;, score=0.572 total time=   0.0s
# [CV 5/5; 25/150] START max_depth=1, max_features=57, n_estimators=10............
# [CV 5/5; 25/150] END max_depth=1, max_features=57, n_estimators=10;, score=0.562 total time=   0.1s
# [CV 1/5; 26/150] START max_depth=1, max_features=57, n_estimators=20............
# [CV 1/5; 26/150] END max_depth=1, max_features=57, n_estimators=20;, score=0.572 total time=   0.2s
# [CV 2/5; 26/150] START max_depth=1, max_features=57, n_estimators=20............
# [CV 2/5; 26/150] END max_depth=1, max_features=57, n_estimators=20;, score=0.577 total time=   0.2s
# [CV 3/5; 26/150] START max_depth=1, max_features=57, n_estimators=20............
# [CV 3/5; 26/150] END max_depth=1, max_features=57, n_estimators=20;, score=0.576 total time=   0.2s
# [CV 4/5; 26/150] START max_depth=1, max_features=57, n_estimators=20............
# [CV 4/5; 26/150] END max_depth=1, max_features=57, n_estimators=20;, score=0.574 total time=   0.2s
# [CV 5/5; 26/150] START max_depth=1, max_features=57, n_estimators=20............
# [CV 5/5; 26/150] END max_depth=1, max_features=57, n_estimators=20;, score=0.573 total time=   0.2s
# [CV 1/5; 27/150] START max_depth=1, max_features=57, n_estimators=50............
# [CV 1/5; 27/150] END max_depth=1, max_features=57, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 2/5; 27/150] START max_depth=1, max_features=57, n_estimators=50............
# [CV 2/5; 27/150] END max_depth=1, max_features=57, n_estimators=50;, score=0.580 total time=   0.7s
# [CV 3/5; 27/150] START max_depth=1, max_features=57, n_estimators=50............
# [CV 3/5; 27/150] END max_depth=1, max_features=57, n_estimators=50;, score=0.585 total time=   0.6s
# [CV 4/5; 27/150] START max_depth=1, max_features=57, n_estimators=50............
# [CV 4/5; 27/150] END max_depth=1, max_features=57, n_estimators=50;, score=0.578 total time=   0.7s
# [CV 5/5; 27/150] START max_depth=1, max_features=57, n_estimators=50............
# [CV 5/5; 27/150] END max_depth=1, max_features=57, n_estimators=50;, score=0.589 total time=   0.7s
# [CV 1/5; 28/150] START max_depth=1, max_features=57, n_estimators=100...........
# [CV 1/5; 28/150] END max_depth=1, max_features=57, n_estimators=100;, score=0.587 total time=   1.3s
# [CV 2/5; 28/150] START max_depth=1, max_features=57, n_estimators=100...........
# [CV 2/5; 28/150] END max_depth=1, max_features=57, n_estimators=100;, score=0.578 total time=   1.6s
# [CV 3/5; 28/150] START max_depth=1, max_features=57, n_estimators=100...........
# [CV 3/5; 28/150] END max_depth=1, max_features=57, n_estimators=100;, score=0.583 total time=   1.4s
# [CV 4/5; 28/150] START max_depth=1, max_features=57, n_estimators=100...........
# [CV 4/5; 28/150] END max_depth=1, max_features=57, n_estimators=100;, score=0.584 total time=   1.4s
# [CV 5/5; 28/150] START max_depth=1, max_features=57, n_estimators=100...........
# [CV 5/5; 28/150] END max_depth=1, max_features=57, n_estimators=100;, score=0.601 total time=   1.8s
# [CV 1/5; 29/150] START max_depth=1, max_features=57, n_estimators=150...........
# [CV 1/5; 29/150] END max_depth=1, max_features=57, n_estimators=150;, score=0.594 total time=   2.2s
# [CV 2/5; 29/150] START max_depth=1, max_features=57, n_estimators=150...........
# [CV 2/5; 29/150] END max_depth=1, max_features=57, n_estimators=150;, score=0.577 total time=   2.0s
# [CV 3/5; 29/150] START max_depth=1, max_features=57, n_estimators=150...........
# [CV 3/5; 29/150] END max_depth=1, max_features=57, n_estimators=150;, score=0.587 total time=   2.2s
# [CV 4/5; 29/150] START max_depth=1, max_features=57, n_estimators=150...........
# [CV 4/5; 29/150] END max_depth=1, max_features=57, n_estimators=150;, score=0.592 total time=   2.1s
# [CV 5/5; 29/150] START max_depth=1, max_features=57, n_estimators=150...........
# [CV 5/5; 29/150] END max_depth=1, max_features=57, n_estimators=150;, score=0.595 total time=   2.0s
# [CV 1/5; 30/150] START max_depth=1, max_features=57, n_estimators=200...........
# [CV 1/5; 30/150] END max_depth=1, max_features=57, n_estimators=200;, score=0.594 total time=   2.8s
# [CV 2/5; 30/150] START max_depth=1, max_features=57, n_estimators=200...........
# [CV 2/5; 30/150] END max_depth=1, max_features=57, n_estimators=200;, score=0.570 total time=   2.7s
# [CV 3/5; 30/150] START max_depth=1, max_features=57, n_estimators=200...........
# [CV 3/5; 30/150] END max_depth=1, max_features=57, n_estimators=200;, score=0.585 total time=   2.9s
# [CV 4/5; 30/150] START max_depth=1, max_features=57, n_estimators=200...........
# [CV 4/5; 30/150] END max_depth=1, max_features=57, n_estimators=200;, score=0.595 total time=   3.0s
# [CV 5/5; 30/150] START max_depth=1, max_features=57, n_estimators=200...........
# [CV 5/5; 30/150] END max_depth=1, max_features=57, n_estimators=200;, score=0.597 total time=   2.7s
# [CV 1/5; 31/150] START max_depth=2, max_features=10, n_estimators=10............
# [CV 1/5; 31/150] END max_depth=2, max_features=10, n_estimators=10;, score=0.578 total time=   0.0s
# [CV 2/5; 31/150] START max_depth=2, max_features=10, n_estimators=10............
# [CV 2/5; 31/150] END max_depth=2, max_features=10, n_estimators=10;, score=0.564 total time=   0.0s
# [CV 3/5; 31/150] START max_depth=2, max_features=10, n_estimators=10............
# [CV 3/5; 31/150] END max_depth=2, max_features=10, n_estimators=10;, score=0.586 total time=   0.0s
# [CV 4/5; 31/150] START max_depth=2, max_features=10, n_estimators=10............
# [CV 4/5; 31/150] END max_depth=2, max_features=10, n_estimators=10;, score=0.576 total time=   0.0s
# [CV 5/5; 31/150] START max_depth=2, max_features=10, n_estimators=10............
# [CV 5/5; 31/150] END max_depth=2, max_features=10, n_estimators=10;, score=0.606 total time=   0.0s
# [CV 1/5; 32/150] START max_depth=2, max_features=10, n_estimators=20............
# [CV 1/5; 32/150] END max_depth=2, max_features=10, n_estimators=20;, score=0.577 total time=   0.2s
# [CV 2/5; 32/150] START max_depth=2, max_features=10, n_estimators=20............
# [CV 2/5; 32/150] END max_depth=2, max_features=10, n_estimators=20;, score=0.573 total time=   0.2s
# [CV 3/5; 32/150] START max_depth=2, max_features=10, n_estimators=20............
# [CV 3/5; 32/150] END max_depth=2, max_features=10, n_estimators=20;, score=0.589 total time=   0.2s
# [CV 4/5; 32/150] START max_depth=2, max_features=10, n_estimators=20............
# [CV 4/5; 32/150] END max_depth=2, max_features=10, n_estimators=20;, score=0.587 total time=   0.2s
# [CV 5/5; 32/150] START max_depth=2, max_features=10, n_estimators=20............
# [CV 5/5; 32/150] END max_depth=2, max_features=10, n_estimators=20;, score=0.603 total time=   0.2s
# [CV 1/5; 33/150] START max_depth=2, max_features=10, n_estimators=50............
# [CV 1/5; 33/150] END max_depth=2, max_features=10, n_estimators=50;, score=0.595 total time=   0.6s
# [CV 2/5; 33/150] START max_depth=2, max_features=10, n_estimators=50............
# [CV 2/5; 33/150] END max_depth=2, max_features=10, n_estimators=50;, score=0.577 total time=   0.6s
# [CV 3/5; 33/150] START max_depth=2, max_features=10, n_estimators=50............
# [CV 3/5; 33/150] END max_depth=2, max_features=10, n_estimators=50;, score=0.584 total time=   0.6s
# [CV 4/5; 33/150] START max_depth=2, max_features=10, n_estimators=50............
# [CV 4/5; 33/150] END max_depth=2, max_features=10, n_estimators=50;, score=0.600 total time=   0.6s
# [CV 5/5; 33/150] START max_depth=2, max_features=10, n_estimators=50............
# [CV 5/5; 33/150] END max_depth=2, max_features=10, n_estimators=50;, score=0.611 total time=   0.6s
# [CV 1/5; 34/150] START max_depth=2, max_features=10, n_estimators=100...........
# [CV 1/5; 34/150] END max_depth=2, max_features=10, n_estimators=100;, score=0.599 total time=   1.3s
# [CV 2/5; 34/150] START max_depth=2, max_features=10, n_estimators=100...........
# [CV 2/5; 34/150] END max_depth=2, max_features=10, n_estimators=100;, score=0.582 total time=   1.4s
# [CV 3/5; 34/150] START max_depth=2, max_features=10, n_estimators=100...........
# [CV 3/5; 34/150] END max_depth=2, max_features=10, n_estimators=100;, score=0.591 total time=   1.4s
# [CV 4/5; 34/150] START max_depth=2, max_features=10, n_estimators=100...........
# [CV 4/5; 34/150] END max_depth=2, max_features=10, n_estimators=100;, score=0.606 total time=   1.5s
# [CV 5/5; 34/150] START max_depth=2, max_features=10, n_estimators=100...........
# [CV 5/5; 34/150] END max_depth=2, max_features=10, n_estimators=100;, score=0.613 total time=   1.3s
# [CV 1/5; 35/150] START max_depth=2, max_features=10, n_estimators=150...........
# [CV 1/5; 35/150] END max_depth=2, max_features=10, n_estimators=150;, score=0.600 total time=   1.9s
# [CV 2/5; 35/150] START max_depth=2, max_features=10, n_estimators=150...........
# [CV 2/5; 35/150] END max_depth=2, max_features=10, n_estimators=150;, score=0.589 total time=   2.2s
# [CV 3/5; 35/150] START max_depth=2, max_features=10, n_estimators=150...........
# [CV 3/5; 35/150] END max_depth=2, max_features=10, n_estimators=150;, score=0.606 total time=   2.1s
# [CV 4/5; 35/150] START max_depth=2, max_features=10, n_estimators=150...........
# [CV 4/5; 35/150] END max_depth=2, max_features=10, n_estimators=150;, score=0.614 total time=   1.9s
# [CV 5/5; 35/150] START max_depth=2, max_features=10, n_estimators=150...........
# [CV 5/5; 35/150] END max_depth=2, max_features=10, n_estimators=150;, score=0.630 total time=   2.2s
# [CV 1/5; 36/150] START max_depth=2, max_features=10, n_estimators=200...........
# [CV 1/5; 36/150] END max_depth=2, max_features=10, n_estimators=200;, score=0.610 total time=   2.6s
# [CV 2/5; 36/150] START max_depth=2, max_features=10, n_estimators=200...........
# [CV 2/5; 36/150] END max_depth=2, max_features=10, n_estimators=200;, score=0.590 total time=   2.9s
# [CV 3/5; 36/150] START max_depth=2, max_features=10, n_estimators=200...........
# [CV 3/5; 36/150] END max_depth=2, max_features=10, n_estimators=200;, score=0.608 total time=   2.6s
# [CV 4/5; 36/150] START max_depth=2, max_features=10, n_estimators=200...........
# [CV 4/5; 36/150] END max_depth=2, max_features=10, n_estimators=200;, score=0.619 total time=   2.6s
# [CV 5/5; 36/150] START max_depth=2, max_features=10, n_estimators=200...........
# [CV 5/5; 36/150] END max_depth=2, max_features=10, n_estimators=200;, score=0.636 total time=   2.7s
# [CV 1/5; 37/150] START max_depth=2, max_features=20, n_estimators=10............
# [CV 1/5; 37/150] END max_depth=2, max_features=20, n_estimators=10;, score=0.567 total time=   0.2s
# [CV 2/5; 37/150] START max_depth=2, max_features=20, n_estimators=10............
# [CV 2/5; 37/150] END max_depth=2, max_features=20, n_estimators=10;, score=0.561 total time=   0.2s
# [CV 3/5; 37/150] START max_depth=2, max_features=20, n_estimators=10............
# [CV 3/5; 37/150] END max_depth=2, max_features=20, n_estimators=10;, score=0.575 total time=   0.2s
# [CV 4/5; 37/150] START max_depth=2, max_features=20, n_estimators=10............
# [CV 4/5; 37/150] END max_depth=2, max_features=20, n_estimators=10;, score=0.584 total time=   0.2s
# [CV 5/5; 37/150] START max_depth=2, max_features=20, n_estimators=10............
# [CV 5/5; 37/150] END max_depth=2, max_features=20, n_estimators=10;, score=0.584 total time=   0.2s
# [CV 1/5; 38/150] START max_depth=2, max_features=20, n_estimators=20............
# [CV 1/5; 38/150] END max_depth=2, max_features=20, n_estimators=20;, score=0.570 total time=   0.4s
# [CV 2/5; 38/150] START max_depth=2, max_features=20, n_estimators=20............
# [CV 2/5; 38/150] END max_depth=2, max_features=20, n_estimators=20;, score=0.565 total time=   0.4s
# [CV 3/5; 38/150] START max_depth=2, max_features=20, n_estimators=20............
# [CV 3/5; 38/150] END max_depth=2, max_features=20, n_estimators=20;, score=0.587 total time=   0.5s
# [CV 4/5; 38/150] START max_depth=2, max_features=20, n_estimators=20............
# [CV 4/5; 38/150] END max_depth=2, max_features=20, n_estimators=20;, score=0.577 total time=   0.4s
# [CV 5/5; 38/150] START max_depth=2, max_features=20, n_estimators=20............
# [CV 5/5; 38/150] END max_depth=2, max_features=20, n_estimators=20;, score=0.611 total time=   0.4s
# [CV 1/5; 39/150] START max_depth=2, max_features=20, n_estimators=50............
# [CV 1/5; 39/150] END max_depth=2, max_features=20, n_estimators=50;, score=0.604 total time=   1.2s
# [CV 2/5; 39/150] START max_depth=2, max_features=20, n_estimators=50............
# [CV 2/5; 39/150] END max_depth=2, max_features=20, n_estimators=50;, score=0.570 total time=   1.4s
# [CV 3/5; 39/150] START max_depth=2, max_features=20, n_estimators=50............
# [CV 3/5; 39/150] END max_depth=2, max_features=20, n_estimators=50;, score=0.595 total time=   1.3s
# [CV 4/5; 39/150] START max_depth=2, max_features=20, n_estimators=50............
# [CV 4/5; 39/150] END max_depth=2, max_features=20, n_estimators=50;, score=0.601 total time=   1.2s
# [CV 5/5; 39/150] START max_depth=2, max_features=20, n_estimators=50............
# [CV 5/5; 39/150] END max_depth=2, max_features=20, n_estimators=50;, score=0.612 total time=   1.1s
# [CV 1/5; 40/150] START max_depth=2, max_features=20, n_estimators=100...........
# [CV 1/5; 40/150] END max_depth=2, max_features=20, n_estimators=100;, score=0.612 total time=   2.3s
# [CV 2/5; 40/150] START max_depth=2, max_features=20, n_estimators=100...........
# [CV 2/5; 40/150] END max_depth=2, max_features=20, n_estimators=100;, score=0.579 total time=   2.5s
# [CV 3/5; 40/150] START max_depth=2, max_features=20, n_estimators=100...........
# [CV 3/5; 40/150] END max_depth=2, max_features=20, n_estimators=100;, score=0.597 total time=   2.3s
# [CV 4/5; 40/150] START max_depth=2, max_features=20, n_estimators=100...........
# [CV 4/5; 40/150] END max_depth=2, max_features=20, n_estimators=100;, score=0.599 total time=   2.5s
# [CV 5/5; 40/150] START max_depth=2, max_features=20, n_estimators=100...........
# [CV 5/5; 40/150] END max_depth=2, max_features=20, n_estimators=100;, score=0.615 total time=   2.5s
# [CV 1/5; 41/150] START max_depth=2, max_features=20, n_estimators=150...........
# [CV 1/5; 41/150] END max_depth=2, max_features=20, n_estimators=150;, score=0.615 total time=   4.0s
# [CV 2/5; 41/150] START max_depth=2, max_features=20, n_estimators=150...........
# [CV 2/5; 41/150] END max_depth=2, max_features=20, n_estimators=150;, score=0.574 total time=   4.0s
# [CV 3/5; 41/150] START max_depth=2, max_features=20, n_estimators=150...........
# [CV 3/5; 41/150] END max_depth=2, max_features=20, n_estimators=150;, score=0.611 total time=   3.6s
# [CV 4/5; 41/150] START max_depth=2, max_features=20, n_estimators=150...........
# [CV 4/5; 41/150] END max_depth=2, max_features=20, n_estimators=150;, score=0.606 total time=   4.0s
# [CV 5/5; 41/150] START max_depth=2, max_features=20, n_estimators=150...........
# [CV 5/5; 41/150] END max_depth=2, max_features=20, n_estimators=150;, score=0.627 total time=   3.8s
# [CV 1/5; 42/150] START max_depth=2, max_features=20, n_estimators=200...........
# [CV 1/5; 42/150] END max_depth=2, max_features=20, n_estimators=200;, score=0.618 total time=   5.5s
# [CV 2/5; 42/150] START max_depth=2, max_features=20, n_estimators=200...........
# [CV 2/5; 42/150] END max_depth=2, max_features=20, n_estimators=200;, score=0.588 total time=   4.8s
# [CV 3/5; 42/150] START max_depth=2, max_features=20, n_estimators=200...........
# [CV 3/5; 42/150] END max_depth=2, max_features=20, n_estimators=200;, score=0.608 total time=   5.0s
# [CV 4/5; 42/150] START max_depth=2, max_features=20, n_estimators=200...........
# [CV 4/5; 42/150] END max_depth=2, max_features=20, n_estimators=200;, score=0.608 total time=   4.8s
# [CV 5/5; 42/150] START max_depth=2, max_features=20, n_estimators=200...........
# [CV 5/5; 42/150] END max_depth=2, max_features=20, n_estimators=200;, score=0.630 total time=   5.4s
# [CV 1/5; 43/150] START max_depth=2, max_features=30, n_estimators=10............
# [CV 1/5; 43/150] END max_depth=2, max_features=30, n_estimators=10;, score=0.580 total time=   0.2s
# [CV 2/5; 43/150] START max_depth=2, max_features=30, n_estimators=10............
# [CV 2/5; 43/150] END max_depth=2, max_features=30, n_estimators=10;, score=0.555 total time=   0.2s
# [CV 3/5; 43/150] START max_depth=2, max_features=30, n_estimators=10............
# [CV 3/5; 43/150] END max_depth=2, max_features=30, n_estimators=10;, score=0.581 total time=   0.2s
# [CV 4/5; 43/150] START max_depth=2, max_features=30, n_estimators=10............
# [CV 4/5; 43/150] END max_depth=2, max_features=30, n_estimators=10;, score=0.580 total time=   0.2s
# [CV 5/5; 43/150] START max_depth=2, max_features=30, n_estimators=10............
# [CV 5/5; 43/150] END max_depth=2, max_features=30, n_estimators=10;, score=0.584 total time=   0.2s
# [CV 1/5; 44/150] START max_depth=2, max_features=30, n_estimators=20............
# [CV 1/5; 44/150] END max_depth=2, max_features=30, n_estimators=20;, score=0.584 total time=   0.6s
# [CV 2/5; 44/150] START max_depth=2, max_features=30, n_estimators=20............
# [CV 2/5; 44/150] END max_depth=2, max_features=30, n_estimators=20;, score=0.571 total time=   0.6s
# [CV 3/5; 44/150] START max_depth=2, max_features=30, n_estimators=20............
# [CV 3/5; 44/150] END max_depth=2, max_features=30, n_estimators=20;, score=0.590 total time=   0.6s
# [CV 4/5; 44/150] START max_depth=2, max_features=30, n_estimators=20............
# [CV 4/5; 44/150] END max_depth=2, max_features=30, n_estimators=20;, score=0.581 total time=   0.6s
# [CV 5/5; 44/150] START max_depth=2, max_features=30, n_estimators=20............
# [CV 5/5; 44/150] END max_depth=2, max_features=30, n_estimators=20;, score=0.598 total time=   0.5s
# [CV 1/5; 45/150] START max_depth=2, max_features=30, n_estimators=50............
# [CV 1/5; 45/150] END max_depth=2, max_features=30, n_estimators=50;, score=0.601 total time=   1.5s
# [CV 2/5; 45/150] START max_depth=2, max_features=30, n_estimators=50............
# [CV 2/5; 45/150] END max_depth=2, max_features=30, n_estimators=50;, score=0.577 total time=   1.3s
# [CV 3/5; 45/150] START max_depth=2, max_features=30, n_estimators=50............
# [CV 3/5; 45/150] END max_depth=2, max_features=30, n_estimators=50;, score=0.592 total time=   1.3s
# [CV 4/5; 45/150] START max_depth=2, max_features=30, n_estimators=50............
# [CV 4/5; 45/150] END max_depth=2, max_features=30, n_estimators=50;, score=0.600 total time=   1.7s
# [CV 5/5; 45/150] START max_depth=2, max_features=30, n_estimators=50............
# [CV 5/5; 45/150] END max_depth=2, max_features=30, n_estimators=50;, score=0.621 total time=   1.3s
# [CV 1/5; 46/150] START max_depth=2, max_features=30, n_estimators=100...........
# [CV 1/5; 46/150] END max_depth=2, max_features=30, n_estimators=100;, score=0.607 total time=   3.0s
# [CV 2/5; 46/150] START max_depth=2, max_features=30, n_estimators=100...........
# [CV 2/5; 46/150] END max_depth=2, max_features=30, n_estimators=100;, score=0.575 total time=   3.0s
# [CV 3/5; 46/150] START max_depth=2, max_features=30, n_estimators=100...........
# [CV 3/5; 46/150] END max_depth=2, max_features=30, n_estimators=100;, score=0.610 total time=   3.2s
# [CV 4/5; 46/150] START max_depth=2, max_features=30, n_estimators=100...........
# [CV 4/5; 46/150] END max_depth=2, max_features=30, n_estimators=100;, score=0.611 total time=   3.2s
# [CV 5/5; 46/150] START max_depth=2, max_features=30, n_estimators=100...........
# [CV 5/5; 46/150] END max_depth=2, max_features=30, n_estimators=100;, score=0.607 total time=   2.6s
# [CV 1/5; 47/150] START max_depth=2, max_features=30, n_estimators=150...........
# [CV 1/5; 47/150] END max_depth=2, max_features=30, n_estimators=150;, score=0.615 total time=   4.3s
# [CV 2/5; 47/150] START max_depth=2, max_features=30, n_estimators=150...........
# [CV 2/5; 47/150] END max_depth=2, max_features=30, n_estimators=150;, score=0.580 total time=   4.4s
# [CV 3/5; 47/150] START max_depth=2, max_features=30, n_estimators=150...........
# [CV 3/5; 47/150] END max_depth=2, max_features=30, n_estimators=150;, score=0.613 total time=   4.4s
# [CV 4/5; 47/150] START max_depth=2, max_features=30, n_estimators=150...........
# [CV 4/5; 47/150] END max_depth=2, max_features=30, n_estimators=150;, score=0.609 total time=   4.3s
# [CV 5/5; 47/150] START max_depth=2, max_features=30, n_estimators=150...........
# [CV 5/5; 47/150] END max_depth=2, max_features=30, n_estimators=150;, score=0.619 total time=   4.5s
# [CV 1/5; 48/150] START max_depth=2, max_features=30, n_estimators=200...........
# [CV 1/5; 48/150] END max_depth=2, max_features=30, n_estimators=200;, score=0.620 total time=   6.1s
# [CV 2/5; 48/150] START max_depth=2, max_features=30, n_estimators=200...........
# [CV 2/5; 48/150] END max_depth=2, max_features=30, n_estimators=200;, score=0.584 total time=   6.3s
# [CV 3/5; 48/150] START max_depth=2, max_features=30, n_estimators=200...........
# [CV 3/5; 48/150] END max_depth=2, max_features=30, n_estimators=200;, score=0.608 total time=   5.6s
# [CV 4/5; 48/150] START max_depth=2, max_features=30, n_estimators=200...........
# [CV 4/5; 48/150] END max_depth=2, max_features=30, n_estimators=200;, score=0.607 total time=   5.7s
# [CV 5/5; 48/150] START max_depth=2, max_features=30, n_estimators=200...........
# [CV 5/5; 48/150] END max_depth=2, max_features=30, n_estimators=200;, score=0.631 total time=   5.9s
# [CV 1/5; 49/150] START max_depth=2, max_features=40, n_estimators=10............
# [CV 1/5; 49/150] END max_depth=2, max_features=40, n_estimators=10;, score=0.580 total time=   0.2s
# [CV 2/5; 49/150] START max_depth=2, max_features=40, n_estimators=10............
# [CV 2/5; 49/150] END max_depth=2, max_features=40, n_estimators=10;, score=0.555 total time=   0.2s
# [CV 3/5; 49/150] START max_depth=2, max_features=40, n_estimators=10............
# [CV 3/5; 49/150] END max_depth=2, max_features=40, n_estimators=10;, score=0.581 total time=   0.2s
# [CV 4/5; 49/150] START max_depth=2, max_features=40, n_estimators=10............
# [CV 4/5; 49/150] END max_depth=2, max_features=40, n_estimators=10;, score=0.580 total time=   0.2s
# [CV 5/5; 49/150] START max_depth=2, max_features=40, n_estimators=10............
# [CV 5/5; 49/150] END max_depth=2, max_features=40, n_estimators=10;, score=0.584 total time=   0.2s
# [CV 1/5; 50/150] START max_depth=2, max_features=40, n_estimators=20............
# [CV 1/5; 50/150] END max_depth=2, max_features=40, n_estimators=20;, score=0.584 total time=   0.6s
# [CV 2/5; 50/150] START max_depth=2, max_features=40, n_estimators=20............
# [CV 2/5; 50/150] END max_depth=2, max_features=40, n_estimators=20;, score=0.571 total time=   0.5s
# [CV 3/5; 50/150] START max_depth=2, max_features=40, n_estimators=20............
# [CV 3/5; 50/150] END max_depth=2, max_features=40, n_estimators=20;, score=0.590 total time=   0.5s
# [CV 4/5; 50/150] START max_depth=2, max_features=40, n_estimators=20............
# [CV 4/5; 50/150] END max_depth=2, max_features=40, n_estimators=20;, score=0.581 total time=   0.4s
# [CV 5/5; 50/150] START max_depth=2, max_features=40, n_estimators=20............
# [CV 5/5; 50/150] END max_depth=2, max_features=40, n_estimators=20;, score=0.598 total time=   0.5s
# [CV 1/5; 51/150] START max_depth=2, max_features=40, n_estimators=50............
# [CV 1/5; 51/150] END max_depth=2, max_features=40, n_estimators=50;, score=0.601 total time=   1.5s
# [CV 2/5; 51/150] START max_depth=2, max_features=40, n_estimators=50............
# [CV 2/5; 51/150] END max_depth=2, max_features=40, n_estimators=50;, score=0.577 total time=   1.4s
# [CV 3/5; 51/150] START max_depth=2, max_features=40, n_estimators=50............
# [CV 3/5; 51/150] END max_depth=2, max_features=40, n_estimators=50;, score=0.592 total time=   1.3s
# [CV 4/5; 51/150] START max_depth=2, max_features=40, n_estimators=50............
# [CV 4/5; 51/150] END max_depth=2, max_features=40, n_estimators=50;, score=0.600 total time=   1.4s
# [CV 5/5; 51/150] START max_depth=2, max_features=40, n_estimators=50............
# [CV 5/5; 51/150] END max_depth=2, max_features=40, n_estimators=50;, score=0.621 total time=   1.5s
# [CV 1/5; 52/150] START max_depth=2, max_features=40, n_estimators=100...........
# [CV 1/5; 52/150] END max_depth=2, max_features=40, n_estimators=100;, score=0.607 total time=   2.8s
# [CV 2/5; 52/150] START max_depth=2, max_features=40, n_estimators=100...........
# [CV 2/5; 52/150] END max_depth=2, max_features=40, n_estimators=100;, score=0.575 total time=   2.7s
# [CV 3/5; 52/150] START max_depth=2, max_features=40, n_estimators=100...........
# [CV 3/5; 52/150] END max_depth=2, max_features=40, n_estimators=100;, score=0.610 total time=   2.8s
# [CV 4/5; 52/150] START max_depth=2, max_features=40, n_estimators=100...........
# [CV 4/5; 52/150] END max_depth=2, max_features=40, n_estimators=100;, score=0.611 total time=   2.8s
# [CV 5/5; 52/150] START max_depth=2, max_features=40, n_estimators=100...........
# [CV 5/5; 52/150] END max_depth=2, max_features=40, n_estimators=100;, score=0.607 total time=   2.7s
# [CV 1/5; 53/150] START max_depth=2, max_features=40, n_estimators=150...........
# [CV 1/5; 53/150] END max_depth=2, max_features=40, n_estimators=150;, score=0.615 total time=   4.3s
# [CV 2/5; 53/150] START max_depth=2, max_features=40, n_estimators=150...........
# [CV 2/5; 53/150] END max_depth=2, max_features=40, n_estimators=150;, score=0.580 total time=   4.1s
# [CV 3/5; 53/150] START max_depth=2, max_features=40, n_estimators=150...........
# [CV 3/5; 53/150] END max_depth=2, max_features=40, n_estimators=150;, score=0.613 total time=   4.5s
# [CV 4/5; 53/150] START max_depth=2, max_features=40, n_estimators=150...........
# [CV 4/5; 53/150] END max_depth=2, max_features=40, n_estimators=150;, score=0.609 total time=   4.3s
# ...
# [CV 3/5; 95/150] START max_depth=5, max_features=10, n_estimators=150...........
# [CV 3/5; 95/150] END max_depth=5, max_features=10, n_estimators=150;, score=0.635 total time=   5.0s
# [CV 4/5; 95/150] START max_depth=5, max_features=10, n_estimators=150...........
# [CV 4/5; 95/150] END max_depth=5, max_features=10, n_estimators=150;, score=0.648 total time=   5.5s
# [CV 5/5; 95/150] START max_depth=5, max_features=10, n_estimators=150...........
# [CV 5/5; 95/150] END max_depth=5, max_features=10, n_estimators=150;, score=0.663 total time=   4.9s
# [CV 1/5; 96/150] START max_depth=5, max_features=10, n_estimators=200...........
# [CV 1/5; 96/150] END max_depth=5, max_features=10, n_estimators=200;, score=0.663 total time=   7.3s
# [CV 2/5; 96/150] START max_depth=5, max_features=10, n_estimators=200...........
# [CV 2/5; 96/150] END max_depth=5, max_features=10, n_estimators=200;, score=0.631 total time=   6.6s
# [CV 3/5; 96/150] START max_depth=5, max_features=10, n_estimators=200...........
# [CV 3/5; 96/150] END max_depth=5, max_features=10, n_estimators=200;, score=0.638 total time=   6.6s
# [CV 4/5; 96/150] START max_depth=5, max_features=10, n_estimators=200...........
# [CV 4/5; 96/150] END max_depth=5, max_features=10, n_estimators=200;, score=0.655 total time=   7.1s
# [CV 5/5; 96/150] START max_depth=5, max_features=10, n_estimators=200...........
# [CV 5/5; 96/150] END max_depth=5, max_features=10, n_estimators=200;, score=0.668 total time=   6.8s
# [CV 1/5; 97/150] START max_depth=5, max_features=20, n_estimators=10............
# [CV 1/5; 97/150] END max_depth=5, max_features=20, n_estimators=10;, score=0.604 total time=   0.5s
# [CV 2/5; 97/150] START max_depth=5, max_features=20, n_estimators=10............
# [CV 2/5; 97/150] END max_depth=5, max_features=20, n_estimators=10;, score=0.612 total time=   0.6s
# [CV 3/5; 97/150] START max_depth=5, max_features=20, n_estimators=10............
# [CV 3/5; 97/150] END max_depth=5, max_features=20, n_estimators=10;, score=0.599 total time=   0.6s
# [CV 4/5; 97/150] START max_depth=5, max_features=20, n_estimators=10............
# [CV 4/5; 97/150] END max_depth=5, max_features=20, n_estimators=10;, score=0.600 total time=   0.6s
# [CV 5/5; 97/150] START max_depth=5, max_features=20, n_estimators=10............
# [CV 5/5; 97/150] END max_depth=5, max_features=20, n_estimators=10;, score=0.611 total time=   0.6s
# [CV 1/5; 98/150] START max_depth=5, max_features=20, n_estimators=20............
# [CV 1/5; 98/150] END max_depth=5, max_features=20, n_estimators=20;, score=0.615 total time=   1.2s
# [CV 2/5; 98/150] START max_depth=5, max_features=20, n_estimators=20............
# [CV 2/5; 98/150] END max_depth=5, max_features=20, n_estimators=20;, score=0.618 total time=   1.2s
# [CV 3/5; 98/150] START max_depth=5, max_features=20, n_estimators=20............
# [CV 3/5; 98/150] END max_depth=5, max_features=20, n_estimators=20;, score=0.629 total time=   1.2s
# [CV 4/5; 98/150] START max_depth=5, max_features=20, n_estimators=20............
# [CV 4/5; 98/150] END max_depth=5, max_features=20, n_estimators=20;, score=0.606 total time=   1.4s
# [CV 5/5; 98/150] START max_depth=5, max_features=20, n_estimators=20............
# [CV 5/5; 98/150] END max_depth=5, max_features=20, n_estimators=20;, score=0.609 total time=   1.2s
# [CV 1/5; 99/150] START max_depth=5, max_features=20, n_estimators=50............
# [CV 1/5; 99/150] END max_depth=5, max_features=20, n_estimators=50;, score=0.631 total time=   3.3s
# [CV 2/5; 99/150] START max_depth=5, max_features=20, n_estimators=50............
# [CV 2/5; 99/150] END max_depth=5, max_features=20, n_estimators=50;, score=0.607 total time=   3.3s
# [CV 3/5; 99/150] START max_depth=5, max_features=20, n_estimators=50............
# [CV 3/5; 99/150] END max_depth=5, max_features=20, n_estimators=50;, score=0.627 total time=   3.2s
# [CV 4/5; 99/150] START max_depth=5, max_features=20, n_estimators=50............
# [CV 4/5; 99/150] END max_depth=5, max_features=20, n_estimators=50;, score=0.626 total time=   3.3s
# [CV 5/5; 99/150] START max_depth=5, max_features=20, n_estimators=50............
# [CV 5/5; 99/150] END max_depth=5, max_features=20, n_estimators=50;, score=0.623 total time=   3.2s
# [CV 1/5; 100/150] START max_depth=5, max_features=20, n_estimators=100..........
# [CV 1/5; 100/150] END max_depth=5, max_features=20, n_estimators=100;, score=0.642 total time=   6.4s
# [CV 2/5; 100/150] START max_depth=5, max_features=20, n_estimators=100..........
# [CV 2/5; 100/150] END max_depth=5, max_features=20, n_estimators=100;, score=0.624 total time=   6.3s
# [CV 3/5; 100/150] START max_depth=5, max_features=20, n_estimators=100..........
# [CV 3/5; 100/150] END max_depth=5, max_features=20, n_estimators=100;, score=0.638 total time=   6.4s
# [CV 4/5; 100/150] START max_depth=5, max_features=20, n_estimators=100..........
# [CV 4/5; 100/150] END max_depth=5, max_features=20, n_estimators=100;, score=0.627 total time=   6.7s
# [CV 5/5; 100/150] START max_depth=5, max_features=20, n_estimators=100..........
# [CV 5/5; 100/150] END max_depth=5, max_features=20, n_estimators=100;, score=0.638 total time=   6.4s
# [CV 1/5; 101/150] START max_depth=5, max_features=20, n_estimators=150..........
# [CV 1/5; 101/150] END max_depth=5, max_features=20, n_estimators=150;, score=0.653 total time=   9.4s
# [CV 2/5; 101/150] START max_depth=5, max_features=20, n_estimators=150..........
# [CV 2/5; 101/150] END max_depth=5, max_features=20, n_estimators=150;, score=0.636 total time=   9.3s
# [CV 3/5; 101/150] START max_depth=5, max_features=20, n_estimators=150..........
# [CV 3/5; 101/150] END max_depth=5, max_features=20, n_estimators=150;, score=0.665 total time=   9.4s
# [CV 4/5; 101/150] START max_depth=5, max_features=20, n_estimators=150..........
# [CV 4/5; 101/150] END max_depth=5, max_features=20, n_estimators=150;, score=0.636 total time=   9.6s
# [CV 5/5; 101/150] START max_depth=5, max_features=20, n_estimators=150..........
# [CV 5/5; 101/150] END max_depth=5, max_features=20, n_estimators=150;, score=0.640 total time=   9.2s
# [CV 1/5; 102/150] START max_depth=5, max_features=20, n_estimators=200..........
# [CV 1/5; 102/150] END max_depth=5, max_features=20, n_estimators=200;, score=0.666 total time=  12.7s
# [CV 2/5; 102/150] START max_depth=5, max_features=20, n_estimators=200..........
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 get_ipython().run_cell_magic('timeit', '-n1 -r1', '\nfrom sklearn.model_selection import GridSearchCV\n\nG = {"max_depth": [1,2,3,5,10],"n_estimators":[10,20,50,100,150,200],"max_features":[10,20,30,40,57]}\n\nGS = GridSearchCV(clf, G, scoring=\'accuracy\', refit=True, cv=5, verbose=10)\n\nacc = GS.fit(X_train, y_train).score(X_test, y_test)\nprint(f\'Precisión: {acc:.1%} con {GS.best_params_}\')\n')
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\interactiveshell.py:2517, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2515 with self.builtin_trap:
#    2516     args = (magic_arg_s, cell)
# -> 2517     result = fn(*args, **kwargs)
#    2519 # The code below prevents the output from being displayed
#    2520 # when using magics with decorator @output_can_be_silenced
#    2521 # when the last Python token in the expression is a ';'.
#    2522 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\magics\execution.py:1189, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1186         if time_number >= 0.2:
#    1187             break
# -> 1189 all_runs = timer.repeat(repeat, number)
#    1190 best = min(all_runs) / number
#    1191 worst = max(all_runs) / number
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\timeit.py:206, in Timer.repeat(self, repeat, number)
#     204 r = []
#     205 for i in range(repeat):
# --> 206     t = self.timeit(number)
#     207     r.append(t)
#     208 return r
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\magics\execution.py:173, in Timer.timeit(self, number)
#     171 gc.disable()
#     172 try:
# --> 173     timing = self.inner(it, self.timer)
#     174 finally:
#     175     if gcold:
#
# File <magic-timeit>:7, in inner(_it, _timer)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1863, in Parallel.__call__(self, iterable)
#    1861     output = self._get_sequential_output(iterable)
#    1862     next(output)
# -> 1863     return output if self.return_generator else list(output)
#    1865 # Let's create an ID that uniquely identifies the current call. If the
#    1866 # call is interrupted early and that the same instance is immediately
#    1867 # re-used, this id will be used to prevent workers that were
#    1868 # concurrently finalizing a task from the previous call to run the
#    1869 # callback.
#    1870 with self._lock:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\joblib\parallel.py:1792, in Parallel._get_sequential_output(self, iterable)
#    1790 self.n_dispatched_batches += 1
#    1791 self.n_dispatched_tasks += 1
# -> 1792 res = func(*args, **kwargs)
#    1793 self.n_completed_tasks += 1
#    1794 self.print_progress()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\utils\parallel.py:127, in _FuncWrapper.__call__(self, *args, **kwargs)
#     125     config = {}
#     126 with config_context(**config):
# --> 127     return self.function(*args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\model_selection\_validation.py:729, in _fit_and_score(estimator, X, y, scorer, train, test, verbose, parameters, fit_params, return_train_score, return_parameters, return_n_test_samples, return_times, return_estimator, split_progress, candidate_progress, error_score)
#     727         estimator.fit(X_train, **fit_params)
#     728     else:
# --> 729         estimator.fit(X_train, y_train, **fit_params)
#     731 except Exception:
#     732     # Note fit time as time until error
#     733     fit_time = time.time() - start_time
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:532, in BaseGradientBoosting.fit(self, X, y, sample_weight, monitor)
#     529     self._resize_state()
#     531 # fit the boosting stages
# --> 532 n_stages = self._fit_stages(
#     533     X_train,
#     534     y_train,
#     535     raw_predictions,
#     536     sample_weight_train,
#     537     self._rng,
#     538     X_val,
#     539     y_val,
#     540     sample_weight_val,
#     541     begin_at_stage,
#     542     monitor,
#     543 )
#     545 # change shape of arrays after fit (early-stopping or additional ests)
#     546 if n_stages != self.estimators_.shape[0]:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:610, in BaseGradientBoosting._fit_stages(self, X, y, raw_predictions, sample_weight, random_state, X_val, y_val, sample_weight_val, begin_at_stage, monitor)
#     603         initial_loss = loss_(
#     604             y[~sample_mask],
#     605             raw_predictions[~sample_mask],
#     606             sample_weight[~sample_mask],
#     607         )
#     609 # fit next stage of trees
# --> 610 raw_predictions = self._fit_stage(
#     611     i,
#     612     X,
#     613     y,
#     614     raw_predictions,
#     615     sample_weight,
#     616     sample_mask,
#     617     random_state,
#     618     X_csc,
#     619     X_csr,
#     620 )
#     622 # track loss
#     623 if do_oob:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb.py:221, in BaseGradientBoosting._fit_stage(self, i, X, y, raw_predictions, sample_weight, sample_mask, random_state, X_csc, X_csr)
#     218 if loss.is_multi_class:
#     219     y = np.array(original_y == k, dtype=np.float64)
# --> 221 residual = loss.negative_gradient(
#     222     y, raw_predictions_copy, k=k, sample_weight=sample_weight
#     223 )
#     225 # induce regression tree on residuals
#     226 tree = DecisionTreeRegressor(
#     227     criterion=self.criterion,
#     228     splitter="best",
#    (...)
#     237     ccp_alpha=self.ccp_alpha,
#     238 )
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\ensemble\_gb_losses.py:702, in BinomialDeviance.negative_gradient(self, y, raw_predictions, **kargs)
#     690 def negative_gradient(self, y, raw_predictions, **kargs):
#     691     """Compute half of the negative gradient.
#     692
#     693     Parameters
#    (...)
#     700         tree ensemble at iteration ``i - 1``.
#     701     """
# --> 702     return y - expit(raw_predictions.ravel())
#
# KeyboardInterrupt:

# %% [markdown]
# No ha dado tiempo a que se ejecute entero, pero la mejor precisión hasta el momento ha sido 66,7%
# Para tratar de mejorar este problema, usamos RandomizedSearch

# %%
# %%timeit -n1 -r1

from sklearn.model_selection import RandomizedSearchCV

G = {"max_depth": [3,5],"n_estimators":[50,100,150,200],"max_features":[10,20,30,40,57]}

GS = RandomizedSearchCV(clf, G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=5, max_features=40, n_estimators=50..............
# [CV 1/5; 1/10] END max_depth=5, max_features=40, n_estimators=50;, score=0.634 total time=   3.5s
# [CV 2/5; 1/10] START max_depth=5, max_features=40, n_estimators=50..............
# [CV 2/5; 1/10] END max_depth=5, max_features=40, n_estimators=50;, score=0.602 total time=   3.5s
# [CV 3/5; 1/10] START max_depth=5, max_features=40, n_estimators=50..............
# [CV 3/5; 1/10] END max_depth=5, max_features=40, n_estimators=50;, score=0.638 total time=   3.6s
# [CV 4/5; 1/10] START max_depth=5, max_features=40, n_estimators=50..............
# [CV 4/5; 1/10] END max_depth=5, max_features=40, n_estimators=50;, score=0.625 total time=   4.3s
# [CV 5/5; 1/10] START max_depth=5, max_features=40, n_estimators=50..............
# [CV 5/5; 1/10] END max_depth=5, max_features=40, n_estimators=50;, score=0.629 total time=   3.5s
# [CV 1/5; 2/10] START max_depth=5, max_features=30, n_estimators=100.............
# [CV 1/5; 2/10] END max_depth=5, max_features=30, n_estimators=100;, score=0.654 total time=   7.3s
# [CV 2/5; 2/10] START max_depth=5, max_features=30, n_estimators=100.............
# [CV 2/5; 2/10] END max_depth=5, max_features=30, n_estimators=100;, score=0.605 total time=   6.9s
# [CV 3/5; 2/10] START max_depth=5, max_features=30, n_estimators=100.............
# [CV 3/5; 2/10] END max_depth=5, max_features=30, n_estimators=100;, score=0.641 total time=   7.3s
# [CV 4/5; 2/10] START max_depth=5, max_features=30, n_estimators=100.............
# [CV 4/5; 2/10] END max_depth=5, max_features=30, n_estimators=100;, score=0.638 total time=   7.5s
# [CV 5/5; 2/10] START max_depth=5, max_features=30, n_estimators=100.............
# [CV 5/5; 2/10] END max_depth=5, max_features=30, n_estimators=100;, score=0.645 total time=   7.9s
# [CV 1/5; 3/10] START max_depth=3, max_features=57, n_estimators=150.............
# [CV 1/5; 3/10] END max_depth=3, max_features=57, n_estimators=150;, score=0.629 total time=   6.5s
# [CV 2/5; 3/10] START max_depth=3, max_features=57, n_estimators=150.............
# [CV 2/5; 3/10] END max_depth=3, max_features=57, n_estimators=150;, score=0.607 total time=   6.8s
# [CV 3/5; 3/10] START max_depth=3, max_features=57, n_estimators=150.............
# [CV 3/5; 3/10] END max_depth=3, max_features=57, n_estimators=150;, score=0.626 total time=   6.2s
# [CV 4/5; 3/10] START max_depth=3, max_features=57, n_estimators=150.............
# [CV 4/5; 3/10] END max_depth=3, max_features=57, n_estimators=150;, score=0.641 total time=   6.3s
# [CV 5/5; 3/10] START max_depth=3, max_features=57, n_estimators=150.............
# [CV 5/5; 3/10] END max_depth=3, max_features=57, n_estimators=150;, score=0.643 total time=   6.5s
# [CV 1/5; 4/10] START max_depth=5, max_features=30, n_estimators=50..............
# [CV 1/5; 4/10] END max_depth=5, max_features=30, n_estimators=50;, score=0.634 total time=   3.6s
# [CV 2/5; 4/10] START max_depth=5, max_features=30, n_estimators=50..............
# [CV 2/5; 4/10] END max_depth=5, max_features=30, n_estimators=50;, score=0.602 total time=   3.6s
# [CV 3/5; 4/10] START max_depth=5, max_features=30, n_estimators=50..............
# [CV 3/5; 4/10] END max_depth=5, max_features=30, n_estimators=50;, score=0.638 total time=   3.7s
# [CV 4/5; 4/10] START max_depth=5, max_features=30, n_estimators=50..............
# [CV 4/5; 4/10] END max_depth=5, max_features=30, n_estimators=50;, score=0.625 total time=   3.8s
# [CV 5/5; 4/10] START max_depth=5, max_features=30, n_estimators=50..............
# [CV 5/5; 4/10] END max_depth=5, max_features=30, n_estimators=50;, score=0.629 total time=   3.8s
# [CV 1/5; 5/10] START max_depth=3, max_features=20, n_estimators=100.............
# [CV 1/5; 5/10] END max_depth=3, max_features=20, n_estimators=100;, score=0.621 total time=   4.2s
# [CV 2/5; 5/10] START max_depth=3, max_features=20, n_estimators=100.............
# [CV 2/5; 5/10] END max_depth=3, max_features=20, n_estimators=100;, score=0.587 total time=   3.9s
# [CV 3/5; 5/10] START max_depth=3, max_features=20, n_estimators=100.............
# [CV 3/5; 5/10] END max_depth=3, max_features=20, n_estimators=100;, score=0.614 total time=   3.8s
# [CV 4/5; 5/10] START max_depth=3, max_features=20, n_estimators=100.............
# [CV 4/5; 5/10] END max_depth=3, max_features=20, n_estimators=100;, score=0.629 total time=   4.2s
# [CV 5/5; 5/10] START max_depth=3, max_features=20, n_estimators=100.............
# [CV 5/5; 5/10] END max_depth=3, max_features=20, n_estimators=100;, score=0.627 total time=   3.7s
# [CV 1/5; 6/10] START max_depth=3, max_features=20, n_estimators=150.............
# [CV 1/5; 6/10] END max_depth=3, max_features=20, n_estimators=150;, score=0.622 total time=   5.6s
# [CV 2/5; 6/10] START max_depth=3, max_features=20, n_estimators=150.............
# [CV 2/5; 6/10] END max_depth=3, max_features=20, n_estimators=150;, score=0.602 total time=   5.8s
# [CV 3/5; 6/10] START max_depth=3, max_features=20, n_estimators=150.............
# [CV 3/5; 6/10] END max_depth=3, max_features=20, n_estimators=150;, score=0.617 total time=   5.8s
# [CV 4/5; 6/10] START max_depth=3, max_features=20, n_estimators=150.............
# [CV 4/5; 6/10] END max_depth=3, max_features=20, n_estimators=150;, score=0.636 total time=   6.1s
# [CV 5/5; 6/10] START max_depth=3, max_features=20, n_estimators=150.............
# [CV 5/5; 6/10] END max_depth=3, max_features=20, n_estimators=150;, score=0.637 total time=   5.8s
# [CV 1/5; 7/10] START max_depth=5, max_features=10, n_estimators=200.............
# [CV 1/5; 7/10] END max_depth=5, max_features=10, n_estimators=200;, score=0.663 total time=   6.4s
# [CV 2/5; 7/10] START max_depth=5, max_features=10, n_estimators=200.............
# [CV 2/5; 7/10] END max_depth=5, max_features=10, n_estimators=200;, score=0.631 total time=   6.9s
# [CV 3/5; 7/10] START max_depth=5, max_features=10, n_estimators=200.............
# [CV 3/5; 7/10] END max_depth=5, max_features=10, n_estimators=200;, score=0.638 total time=   7.1s
# [CV 4/5; 7/10] START max_depth=5, max_features=10, n_estimators=200.............
# [CV 4/5; 7/10] END max_depth=5, max_features=10, n_estimators=200;, score=0.655 total time=   7.0s
# [CV 5/5; 7/10] START max_depth=5, max_features=10, n_estimators=200.............
# [CV 5/5; 7/10] END max_depth=5, max_features=10, n_estimators=200;, score=0.668 total time=   6.8s
# [CV 1/5; 8/10] START max_depth=3, max_features=30, n_estimators=100.............
# [CV 1/5; 8/10] END max_depth=3, max_features=30, n_estimators=100;, score=0.619 total time=   4.5s
# [CV 2/5; 8/10] START max_depth=3, max_features=30, n_estimators=100.............
# [CV 2/5; 8/10] END max_depth=3, max_features=30, n_estimators=100;, score=0.597 total time=   4.6s
# [CV 3/5; 8/10] START max_depth=3, max_features=30, n_estimators=100.............
# [CV 3/5; 8/10] END max_depth=3, max_features=30, n_estimators=100;, score=0.622 total time=   4.3s
# [CV 4/5; 8/10] START max_depth=3, max_features=30, n_estimators=100.............
# [CV 4/5; 8/10] END max_depth=3, max_features=30, n_estimators=100;, score=0.622 total time=   4.5s
# [CV 5/5; 8/10] START max_depth=3, max_features=30, n_estimators=100.............
# [CV 5/5; 8/10] END max_depth=3, max_features=30, n_estimators=100;, score=0.638 total time=   4.8s
# [CV 1/5; 9/10] START max_depth=3, max_features=40, n_estimators=150.............
# [CV 1/5; 9/10] END max_depth=3, max_features=40, n_estimators=150;, score=0.629 total time=   6.2s
# [CV 2/5; 9/10] START max_depth=3, max_features=40, n_estimators=150.............
# [CV 2/5; 9/10] END max_depth=3, max_features=40, n_estimators=150;, score=0.607 total time=   6.4s
# [CV 3/5; 9/10] START max_depth=3, max_features=40, n_estimators=150.............
# [CV 3/5; 9/10] END max_depth=3, max_features=40, n_estimators=150;, score=0.626 total time=   6.2s
# [CV 4/5; 9/10] START max_depth=3, max_features=40, n_estimators=150.............
# [CV 4/5; 9/10] END max_depth=3, max_features=40, n_estimators=150;, score=0.641 total time=   6.2s
# [CV 5/5; 9/10] START max_depth=3, max_features=40, n_estimators=150.............
# [CV 5/5; 9/10] END max_depth=3, max_features=40, n_estimators=150;, score=0.643 total time=   6.7s
# [CV 1/5; 10/10] START max_depth=5, max_features=57, n_estimators=200............
# [CV 1/5; 10/10] END max_depth=5, max_features=57, n_estimators=200;, score=0.666 total time=  14.4s
# [CV 2/5; 10/10] START max_depth=5, max_features=57, n_estimators=200............
# [CV 2/5; 10/10] END max_depth=5, max_features=57, n_estimators=200;, score=0.618 total time=  14.4s
# [CV 3/5; 10/10] START max_depth=5, max_features=57, n_estimators=200............
# [CV 3/5; 10/10] END max_depth=5, max_features=57, n_estimators=200;, score=0.652 total time=  15.0s
# [CV 4/5; 10/10] START max_depth=5, max_features=57, n_estimators=200............
# [CV 4/5; 10/10] END max_depth=5, max_features=57, n_estimators=200;, score=0.661 total time=  14.0s
# [CV 5/5; 10/10] START max_depth=5, max_features=57, n_estimators=200............
# [CV 5/5; 10/10] END max_depth=5, max_features=57, n_estimators=200;, score=0.658 total time=  15.4s
# Precisión: 69.8% con {'n_estimators': 200, 'max_features': 57, 'max_depth': 5}
# 5min 39s ± 0 ns per loop (mean ± std. dev. of 1 run, 1 loop each)

# %% [markdown]
# En este caso el tiempo es mucho menor y la precisión mejora notablemente

# %% [markdown]
# Aplicamos normalización de los datos y PCA antes del GradientBoosting para mejorar el error y el tiempo

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

scaler = StandardScaler()
pca = PCA()

pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("clf", clf)])

G = {"pca__n_components": [5,25,50], "clf__max_depth": [1,3,5],"clf__n_estimators":[50,100],"clf__max_features":[10,25,40,57]}
GS = GridSearchCV(pipe, G, scoring='accuracy', refit=True, cv=3, verbose=10)
acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 3 folds for each of 72 candidates, totalling 216 fits
# [CV 1/3; 1/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 1/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.542 total time=   0.4s
# [CV 2/3; 1/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 1/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.543 total time=   0.4s
# [CV 3/3; 1/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 1/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.536 total time=   0.3s
# [CV 1/3; 2/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 2/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 2/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 2/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 2/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 2/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 3/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 3/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 3/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 3/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 3/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 3/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 4/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 4/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.544 total time=   0.7s
# [CV 2/3; 4/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 4/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.537 total time=   0.8s
# [CV 3/3; 4/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 4/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.542 total time=   0.7s
# [CV 1/3; 5/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 5/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 5/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 5/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 5/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 5/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 6/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 6/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 6/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 6/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 6/72] START clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 6/72] END clf__max_depth=1, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 7/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 7/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.544 total time=   0.3s
# [CV 2/3; 7/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 7/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.539 total time=   0.4s
# [CV 3/3; 7/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 7/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.538 total time=   0.3s
# [CV 1/3; 8/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 8/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 8/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 8/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 8/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 8/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 9/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 9/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 9/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 9/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 9/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 9/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 10/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 10/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.544 total time=   0.7s
# [CV 2/3; 10/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 10/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.531 total time=   0.8s
# [CV 3/3; 10/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 10/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.538 total time=   0.8s
# [CV 1/3; 11/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 11/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 11/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 11/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 11/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 11/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 12/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 12/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 12/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 12/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 12/72] START clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 12/72] END clf__max_depth=1, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 13/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 13/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.544 total time=   0.3s
# [CV 2/3; 13/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 13/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.528 total time=   0.4s
# [CV 3/3; 13/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 13/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.538 total time=   0.4s
# [CV 1/3; 14/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 14/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 14/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 14/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 14/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 14/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 15/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 15/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 15/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 15/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 15/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 15/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 16/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 16/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.546 total time=   0.7s
# [CV 2/3; 16/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 16/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.535 total time=   0.8s
# [CV 3/3; 16/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 16/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.543 total time=   0.8s
# [CV 1/3; 17/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 17/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 17/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 17/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 17/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 17/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 18/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 18/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 18/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 18/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 18/72] START clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 18/72] END clf__max_depth=1, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 19/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 19/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.544 total time=   0.4s
# [CV 2/3; 19/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 19/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.533 total time=   0.3s
# [CV 3/3; 19/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 19/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.539 total time=   0.3s
# [CV 1/3; 20/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 20/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 20/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 20/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 20/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 20/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 21/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 21/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 21/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 21/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 21/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 21/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 22/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 22/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.544 total time=   0.7s
# [CV 2/3; 22/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 22/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.533 total time=   0.7s
# [CV 3/3; 22/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 22/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.535 total time=   0.8s
# [CV 1/3; 23/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 23/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 23/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 23/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 23/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 23/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 24/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 24/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 24/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 24/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 24/72] START clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 24/72] END clf__max_depth=1, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 25/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 25/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.539 total time=   1.1s
# [CV 2/3; 25/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 25/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.546 total time=   1.1s
# [CV 3/3; 25/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 25/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.523 total time=   1.1s
# [CV 1/3; 26/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 26/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 26/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 26/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 26/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 26/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 27/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 27/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 27/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 27/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 27/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 27/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 28/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 28/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.539 total time=   2.3s
# [CV 2/3; 28/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 28/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.544 total time=   2.4s
# [CV 3/3; 28/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 28/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.519 total time=   3.1s
# [CV 1/3; 29/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 29/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 29/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 29/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 29/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 29/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 30/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 30/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 30/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 30/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 30/72] START clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 30/72] END clf__max_depth=3, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 31/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 31/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.538 total time=   1.6s
# [CV 2/3; 31/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 31/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.539 total time=   1.5s
# [CV 3/3; 31/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 31/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.518 total time=   1.1s
# [CV 1/3; 32/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 32/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 32/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 32/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 32/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 32/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 33/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 33/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 33/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 33/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 33/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 33/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 34/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 34/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.543 total time=   2.3s
# [CV 2/3; 34/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 34/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.543 total time=   2.4s
# [CV 3/3; 34/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 34/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.525 total time=   2.2s
# [CV 1/3; 35/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 35/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 35/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 35/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 35/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 35/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 36/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 36/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 36/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 36/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 36/72] START clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 36/72] END clf__max_depth=3, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 37/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 37/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.546 total time=   1.0s
# [CV 2/3; 37/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 37/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.543 total time=   1.0s
# [CV 3/3; 37/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 37/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.515 total time=   1.2s
# [CV 1/3; 38/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 38/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 38/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 38/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 38/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 38/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 39/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 39/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 39/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 39/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 39/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 39/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 40/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 40/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.541 total time=   2.6s
# [CV 2/3; 40/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 40/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.535 total time=   2.2s
# [CV 3/3; 40/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 40/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.525 total time=   2.6s
# [CV 1/3; 41/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 41/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 41/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 41/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 41/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 41/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 42/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 42/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 42/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 42/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 42/72] START clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 42/72] END clf__max_depth=3, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 43/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 43/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.537 total time=   1.2s
# [CV 2/3; 43/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 43/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.544 total time=   1.1s
# [CV 3/3; 43/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 43/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.526 total time=   1.1s
# [CV 1/3; 44/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 44/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 44/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 44/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 44/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 44/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 45/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 45/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 45/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 45/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 45/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 45/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 46/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 46/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.548 total time=   2.5s
# [CV 2/3; 46/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 46/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.543 total time=   2.4s
# [CV 3/3; 46/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 46/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.519 total time=   2.6s
# [CV 1/3; 47/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 47/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 47/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 47/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 47/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 47/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 48/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 48/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 48/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 48/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 48/72] START clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 48/72] END clf__max_depth=3, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 49/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 49/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.534 total time=   2.0s
# [CV 2/3; 49/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 49/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.541 total time=   1.9s
# [CV 3/3; 49/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 49/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=5;, score=0.519 total time=   2.0s
# [CV 1/3; 50/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 50/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 50/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 50/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 50/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 50/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 51/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 51/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 51/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 51/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 51/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 51/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 52/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 52/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.544 total time=   3.8s
# [CV 2/3; 52/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 52/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.526 total time=   3.6s
# [CV 3/3; 52/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 52/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=5;, score=0.526 total time=   3.5s
# [CV 1/3; 53/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 53/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 53/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 53/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 53/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 53/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 54/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 54/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 54/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 54/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 54/72] START clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 54/72] END clf__max_depth=5, clf__max_features=10, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 55/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 55/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.543 total time=   1.7s
# [CV 2/3; 55/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 55/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.535 total time=   1.8s
# [CV 3/3; 55/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 55/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=5;, score=0.517 total time=   1.7s
# [CV 1/3; 56/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 56/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 56/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 56/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 56/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 56/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 57/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 57/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 57/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 57/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 57/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 57/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 58/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 58/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.548 total time=   3.6s
# [CV 2/3; 58/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 58/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.541 total time=   3.8s
# [CV 3/3; 58/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 58/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=5;, score=0.519 total time=   4.0s
# [CV 1/3; 59/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 59/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 59/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 59/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 59/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 59/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 60/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 60/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 60/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 60/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 60/72] START clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 60/72] END clf__max_depth=5, clf__max_features=25, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 61/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 61/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.534 total time=   2.0s
# [CV 2/3; 61/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 61/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.545 total time=   1.8s
# [CV 3/3; 61/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 61/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=5;, score=0.515 total time=   2.0s
# [CV 1/3; 62/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 62/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 62/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 62/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 62/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 62/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 63/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 63/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 63/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 63/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 63/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 63/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 64/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 64/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.548 total time=   3.7s
# [CV 2/3; 64/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 64/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.533 total time=   3.6s
# [CV 3/3; 64/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 64/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=5;, score=0.522 total time=   3.9s
# [CV 1/3; 65/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 65/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 65/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 65/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 65/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 65/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 66/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 66/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 66/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 66/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 66/72] START clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 66/72] END clf__max_depth=5, clf__max_features=40, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 67/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 1/3; 67/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.544 total time=   1.8s
# [CV 2/3; 67/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 2/3; 67/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.542 total time=   1.9s
# [CV 3/3; 67/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5
# [CV 3/3; 67/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=5;, score=0.517 total time=   1.8s
# [CV 1/3; 68/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 1/3; 68/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 68/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 2/3; 68/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 68/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25
# [CV 3/3; 68/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 69/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 1/3; 69/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 69/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 2/3; 69/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 69/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50
# [CV 3/3; 69/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=50, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/3; 70/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 1/3; 70/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.540 total time=   3.8s
# [CV 2/3; 70/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 2/3; 70/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.527 total time=   3.8s
# [CV 3/3; 70/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5
# [CV 3/3; 70/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=5;, score=0.525 total time=   3.5s
# [CV 1/3; 71/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 1/3; 71/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 2/3; 71/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 2/3; 71/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 3/3; 71/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25
# [CV 3/3; 71/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=25;, score=nan total time=   0.0s
# [CV 1/3; 72/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 1/3; 72/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/3; 72/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 2/3; 72/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/3; 72/72] START clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50
# [CV 3/3; 72/72] END clf__max_depth=5, clf__max_features=57, clf__n_estimators=100, pca__n_components=50;, score=nan total time=   0.0s
# Precisión: 54.0% con {'clf__max_depth': 1, 'clf__max_features': 40, 'clf__n_estimators': 100, 'pca__n_components': 5}

# %% [markdown]
# Aunque el tiempo mejora usando PCA y reducción de la dimensionalidad, la precisión empeora

# %% [markdown]
# ## Ejercicio 2
#
# De forma similar al ejercicio anterior, estudia el error de KNeighbors con ajuste de hiper-parámetros mediante alguna de las técnicas de optimización explicadas en las prácticas

# %% [markdown]
# Por defecto:

# %%
from sklearn.neighbors import KNeighborsClassifier

kv = KNeighborsClassifier()
acc=kv.fit(X_train,y_train).score(X_test,y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 57.8%

# %% [markdown]
# Búsqueda de los mejores parámetros:

# %%
import warnings; warnings.filterwarnings('ignore')
from sklearn.model_selection import train_test_split, GridSearchCV
G = {'n_neighbors': [1,2,5,10], 'weights':['uniform', 'distance'], 'leaf_size': [5,10,20,30], 'p': [1,2]}
GS = GridSearchCV(kv, G, scoring='accuracy', refit=True, cv=5, verbose=10)
acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 64 candidates, totalling 320 fits
# [CV 1/5; 1/64] START leaf_size=5, n_neighbors=1, p=1, weights=uniform...........
# [CV 1/5; 1/64] END leaf_size=5, n_neighbors=1, p=1, weights=uniform;, score=0.593 total time=   0.0s
# [CV 2/5; 1/64] START leaf_size=5, n_neighbors=1, p=1, weights=uniform...........
# [CV 2/5; 1/64] END leaf_size=5, n_neighbors=1, p=1, weights=uniform;, score=0.582 total time=   0.0s
# [CV 3/5; 1/64] START leaf_size=5, n_neighbors=1, p=1, weights=uniform...........
# [CV 3/5; 1/64] END leaf_size=5, n_neighbors=1, p=1, weights=uniform;, score=0.607 total time=   0.0s
# [CV 4/5; 1/64] START leaf_size=5, n_neighbors=1, p=1, weights=uniform...........
# [CV 4/5; 1/64] END leaf_size=5, n_neighbors=1, p=1, weights=uniform;, score=0.603 total time=   0.0s
# [CV 5/5; 1/64] START leaf_size=5, n_neighbors=1, p=1, weights=uniform...........
# [CV 5/5; 1/64] END leaf_size=5, n_neighbors=1, p=1, weights=uniform;, score=0.606 total time=   0.0s
# [CV 1/5; 2/64] START leaf_size=5, n_neighbors=1, p=1, weights=distance..........
# [CV 1/5; 2/64] END leaf_size=5, n_neighbors=1, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 2/64] START leaf_size=5, n_neighbors=1, p=1, weights=distance..........
# [CV 2/5; 2/64] END leaf_size=5, n_neighbors=1, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 2/64] START leaf_size=5, n_neighbors=1, p=1, weights=distance..........
# [CV 3/5; 2/64] END leaf_size=5, n_neighbors=1, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 2/64] START leaf_size=5, n_neighbors=1, p=1, weights=distance..........
# [CV 4/5; 2/64] END leaf_size=5, n_neighbors=1, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 2/64] START leaf_size=5, n_neighbors=1, p=1, weights=distance..........
# [CV 5/5; 2/64] END leaf_size=5, n_neighbors=1, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 3/64] START leaf_size=5, n_neighbors=1, p=2, weights=uniform...........
# [CV 1/5; 3/64] END leaf_size=5, n_neighbors=1, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 2/5; 3/64] START leaf_size=5, n_neighbors=1, p=2, weights=uniform...........
# [CV 2/5; 3/64] END leaf_size=5, n_neighbors=1, p=2, weights=uniform;, score=0.566 total time=   0.0s
# [CV 3/5; 3/64] START leaf_size=5, n_neighbors=1, p=2, weights=uniform...........
# [CV 3/5; 3/64] END leaf_size=5, n_neighbors=1, p=2, weights=uniform;, score=0.587 total time=   0.0s
# [CV 4/5; 3/64] START leaf_size=5, n_neighbors=1, p=2, weights=uniform...........
# [CV 4/5; 3/64] END leaf_size=5, n_neighbors=1, p=2, weights=uniform;, score=0.582 total time=   0.0s
# [CV 5/5; 3/64] START leaf_size=5, n_neighbors=1, p=2, weights=uniform...........
# [CV 5/5; 3/64] END leaf_size=5, n_neighbors=1, p=2, weights=uniform;, score=0.593 total time=   0.0s
# [CV 1/5; 4/64] START leaf_size=5, n_neighbors=1, p=2, weights=distance..........
# [CV 1/5; 4/64] END leaf_size=5, n_neighbors=1, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 4/64] START leaf_size=5, n_neighbors=1, p=2, weights=distance..........
# [CV 2/5; 4/64] END leaf_size=5, n_neighbors=1, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 4/64] START leaf_size=5, n_neighbors=1, p=2, weights=distance..........
# [CV 3/5; 4/64] END leaf_size=5, n_neighbors=1, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 4/64] START leaf_size=5, n_neighbors=1, p=2, weights=distance..........
# [CV 4/5; 4/64] END leaf_size=5, n_neighbors=1, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 4/64] START leaf_size=5, n_neighbors=1, p=2, weights=distance..........
# [CV 5/5; 4/64] END leaf_size=5, n_neighbors=1, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 5/64] START leaf_size=5, n_neighbors=2, p=1, weights=uniform...........
# [CV 1/5; 5/64] END leaf_size=5, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 2/5; 5/64] START leaf_size=5, n_neighbors=2, p=1, weights=uniform...........
# [CV 2/5; 5/64] END leaf_size=5, n_neighbors=2, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 3/5; 5/64] START leaf_size=5, n_neighbors=2, p=1, weights=uniform...........
# [CV 3/5; 5/64] END leaf_size=5, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 4/5; 5/64] START leaf_size=5, n_neighbors=2, p=1, weights=uniform...........
# [CV 4/5; 5/64] END leaf_size=5, n_neighbors=2, p=1, weights=uniform;, score=0.566 total time=   0.0s
# [CV 5/5; 5/64] START leaf_size=5, n_neighbors=2, p=1, weights=uniform...........
# [CV 5/5; 5/64] END leaf_size=5, n_neighbors=2, p=1, weights=uniform;, score=0.589 total time=   0.0s
# [CV 1/5; 6/64] START leaf_size=5, n_neighbors=2, p=1, weights=distance..........
# [CV 1/5; 6/64] END leaf_size=5, n_neighbors=2, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 6/64] START leaf_size=5, n_neighbors=2, p=1, weights=distance..........
# [CV 2/5; 6/64] END leaf_size=5, n_neighbors=2, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 6/64] START leaf_size=5, n_neighbors=2, p=1, weights=distance..........
# [CV 3/5; 6/64] END leaf_size=5, n_neighbors=2, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 6/64] START leaf_size=5, n_neighbors=2, p=1, weights=distance..........
# [CV 4/5; 6/64] END leaf_size=5, n_neighbors=2, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 6/64] START leaf_size=5, n_neighbors=2, p=1, weights=distance..........
# [CV 5/5; 6/64] END leaf_size=5, n_neighbors=2, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 7/64] START leaf_size=5, n_neighbors=2, p=2, weights=uniform...........
# [CV 1/5; 7/64] END leaf_size=5, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 2/5; 7/64] START leaf_size=5, n_neighbors=2, p=2, weights=uniform...........
# [CV 2/5; 7/64] END leaf_size=5, n_neighbors=2, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 7/64] START leaf_size=5, n_neighbors=2, p=2, weights=uniform...........
# [CV 3/5; 7/64] END leaf_size=5, n_neighbors=2, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 7/64] START leaf_size=5, n_neighbors=2, p=2, weights=uniform...........
# [CV 4/5; 7/64] END leaf_size=5, n_neighbors=2, p=2, weights=uniform;, score=0.551 total time=   0.0s
# [CV 5/5; 7/64] START leaf_size=5, n_neighbors=2, p=2, weights=uniform...........
# [CV 5/5; 7/64] END leaf_size=5, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 1/5; 8/64] START leaf_size=5, n_neighbors=2, p=2, weights=distance..........
# [CV 1/5; 8/64] END leaf_size=5, n_neighbors=2, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 8/64] START leaf_size=5, n_neighbors=2, p=2, weights=distance..........
# [CV 2/5; 8/64] END leaf_size=5, n_neighbors=2, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 8/64] START leaf_size=5, n_neighbors=2, p=2, weights=distance..........
# [CV 3/5; 8/64] END leaf_size=5, n_neighbors=2, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 8/64] START leaf_size=5, n_neighbors=2, p=2, weights=distance..........
# [CV 4/5; 8/64] END leaf_size=5, n_neighbors=2, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 8/64] START leaf_size=5, n_neighbors=2, p=2, weights=distance..........
# [CV 5/5; 8/64] END leaf_size=5, n_neighbors=2, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 9/64] START leaf_size=5, n_neighbors=5, p=1, weights=uniform...........
# [CV 1/5; 9/64] END leaf_size=5, n_neighbors=5, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 2/5; 9/64] START leaf_size=5, n_neighbors=5, p=1, weights=uniform...........
# [CV 2/5; 9/64] END leaf_size=5, n_neighbors=5, p=1, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 9/64] START leaf_size=5, n_neighbors=5, p=1, weights=uniform...........
# [CV 3/5; 9/64] END leaf_size=5, n_neighbors=5, p=1, weights=uniform;, score=0.581 total time=   0.0s
# [CV 4/5; 9/64] START leaf_size=5, n_neighbors=5, p=1, weights=uniform...........
# [CV 4/5; 9/64] END leaf_size=5, n_neighbors=5, p=1, weights=uniform;, score=0.533 total time=   0.0s
# [CV 5/5; 9/64] START leaf_size=5, n_neighbors=5, p=1, weights=uniform...........
# [CV 5/5; 9/64] END leaf_size=5, n_neighbors=5, p=1, weights=uniform;, score=0.576 total time=   0.0s
# [CV 1/5; 10/64] START leaf_size=5, n_neighbors=5, p=1, weights=distance.........
# [CV 1/5; 10/64] END leaf_size=5, n_neighbors=5, p=1, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 10/64] START leaf_size=5, n_neighbors=5, p=1, weights=distance.........
# [CV 2/5; 10/64] END leaf_size=5, n_neighbors=5, p=1, weights=distance;, score=0.572 total time=   0.0s
# [CV 3/5; 10/64] START leaf_size=5, n_neighbors=5, p=1, weights=distance.........
# [CV 3/5; 10/64] END leaf_size=5, n_neighbors=5, p=1, weights=distance;, score=0.605 total time=   0.0s
# [CV 4/5; 10/64] START leaf_size=5, n_neighbors=5, p=1, weights=distance.........
# [CV 4/5; 10/64] END leaf_size=5, n_neighbors=5, p=1, weights=distance;, score=0.564 total time=   0.0s
# [CV 5/5; 10/64] START leaf_size=5, n_neighbors=5, p=1, weights=distance.........
# [CV 5/5; 10/64] END leaf_size=5, n_neighbors=5, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 1/5; 11/64] START leaf_size=5, n_neighbors=5, p=2, weights=uniform..........
# [CV 1/5; 11/64] END leaf_size=5, n_neighbors=5, p=2, weights=uniform;, score=0.543 total time=   0.0s
# [CV 2/5; 11/64] START leaf_size=5, n_neighbors=5, p=2, weights=uniform..........
# [CV 2/5; 11/64] END leaf_size=5, n_neighbors=5, p=2, weights=uniform;, score=0.534 total time=   0.0s
# [CV 3/5; 11/64] START leaf_size=5, n_neighbors=5, p=2, weights=uniform..........
# [CV 3/5; 11/64] END leaf_size=5, n_neighbors=5, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 11/64] START leaf_size=5, n_neighbors=5, p=2, weights=uniform..........
# [CV 4/5; 11/64] END leaf_size=5, n_neighbors=5, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 5/5; 11/64] START leaf_size=5, n_neighbors=5, p=2, weights=uniform..........
# [CV 5/5; 11/64] END leaf_size=5, n_neighbors=5, p=2, weights=uniform;, score=0.568 total time=   0.0s
# [CV 1/5; 12/64] START leaf_size=5, n_neighbors=5, p=2, weights=distance.........
# [CV 1/5; 12/64] END leaf_size=5, n_neighbors=5, p=2, weights=distance;, score=0.555 total time=   0.0s
# [CV 2/5; 12/64] START leaf_size=5, n_neighbors=5, p=2, weights=distance.........
# [CV 2/5; 12/64] END leaf_size=5, n_neighbors=5, p=2, weights=distance;, score=0.554 total time=   0.0s
# [CV 3/5; 12/64] START leaf_size=5, n_neighbors=5, p=2, weights=distance.........
# [CV 3/5; 12/64] END leaf_size=5, n_neighbors=5, p=2, weights=distance;, score=0.575 total time=   0.0s
# [CV 4/5; 12/64] START leaf_size=5, n_neighbors=5, p=2, weights=distance.........
# [CV 4/5; 12/64] END leaf_size=5, n_neighbors=5, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 5/5; 12/64] START leaf_size=5, n_neighbors=5, p=2, weights=distance.........
# [CV 5/5; 12/64] END leaf_size=5, n_neighbors=5, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 1/5; 13/64] START leaf_size=5, n_neighbors=10, p=1, weights=uniform.........
# [CV 1/5; 13/64] END leaf_size=5, n_neighbors=10, p=1, weights=uniform;, score=0.535 total time=   0.0s
# [CV 2/5; 13/64] START leaf_size=5, n_neighbors=10, p=1, weights=uniform.........
# [CV 2/5; 13/64] END leaf_size=5, n_neighbors=10, p=1, weights=uniform;, score=0.524 total time=   0.0s
# [CV 3/5; 13/64] START leaf_size=5, n_neighbors=10, p=1, weights=uniform.........
# [CV 3/5; 13/64] END leaf_size=5, n_neighbors=10, p=1, weights=uniform;, score=0.548 total time=   0.0s
# [CV 4/5; 13/64] START leaf_size=5, n_neighbors=10, p=1, weights=uniform.........
# [CV 4/5; 13/64] END leaf_size=5, n_neighbors=10, p=1, weights=uniform;, score=0.541 total time=   0.0s
# [CV 5/5; 13/64] START leaf_size=5, n_neighbors=10, p=1, weights=uniform.........
# [CV 5/5; 13/64] END leaf_size=5, n_neighbors=10, p=1, weights=uniform;, score=0.543 total time=   0.0s
# [CV 1/5; 14/64] START leaf_size=5, n_neighbors=10, p=1, weights=distance........
# [CV 1/5; 14/64] END leaf_size=5, n_neighbors=10, p=1, weights=distance;, score=0.571 total time=   0.0s
# [CV 2/5; 14/64] START leaf_size=5, n_neighbors=10, p=1, weights=distance........
# [CV 2/5; 14/64] END leaf_size=5, n_neighbors=10, p=1, weights=distance;, score=0.555 total time=   0.0s
# [CV 3/5; 14/64] START leaf_size=5, n_neighbors=10, p=1, weights=distance........
# [CV 3/5; 14/64] END leaf_size=5, n_neighbors=10, p=1, weights=distance;, score=0.584 total time=   0.0s
# [CV 4/5; 14/64] START leaf_size=5, n_neighbors=10, p=1, weights=distance........
# [CV 4/5; 14/64] END leaf_size=5, n_neighbors=10, p=1, weights=distance;, score=0.574 total time=   0.0s
# [CV 5/5; 14/64] START leaf_size=5, n_neighbors=10, p=1, weights=distance........
# [CV 5/5; 14/64] END leaf_size=5, n_neighbors=10, p=1, weights=distance;, score=0.576 total time=   0.0s
# [CV 1/5; 15/64] START leaf_size=5, n_neighbors=10, p=2, weights=uniform.........
# [CV 1/5; 15/64] END leaf_size=5, n_neighbors=10, p=2, weights=uniform;, score=0.538 total time=   0.0s
# [CV 2/5; 15/64] START leaf_size=5, n_neighbors=10, p=2, weights=uniform.........
# [CV 2/5; 15/64] END leaf_size=5, n_neighbors=10, p=2, weights=uniform;, score=0.542 total time=   0.0s
# [CV 3/5; 15/64] START leaf_size=5, n_neighbors=10, p=2, weights=uniform.........
# [CV 3/5; 15/64] END leaf_size=5, n_neighbors=10, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 4/5; 15/64] START leaf_size=5, n_neighbors=10, p=2, weights=uniform.........
# [CV 4/5; 15/64] END leaf_size=5, n_neighbors=10, p=2, weights=uniform;, score=0.535 total time=   0.0s
# [CV 5/5; 15/64] START leaf_size=5, n_neighbors=10, p=2, weights=uniform.........
# [CV 5/5; 15/64] END leaf_size=5, n_neighbors=10, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 1/5; 16/64] START leaf_size=5, n_neighbors=10, p=2, weights=distance........
# [CV 1/5; 16/64] END leaf_size=5, n_neighbors=10, p=2, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 16/64] START leaf_size=5, n_neighbors=10, p=2, weights=distance........
# [CV 2/5; 16/64] END leaf_size=5, n_neighbors=10, p=2, weights=distance;, score=0.552 total time=   0.0s
# [CV 3/5; 16/64] START leaf_size=5, n_neighbors=10, p=2, weights=distance........
# [CV 3/5; 16/64] END leaf_size=5, n_neighbors=10, p=2, weights=distance;, score=0.577 total time=   0.0s
# [CV 4/5; 16/64] START leaf_size=5, n_neighbors=10, p=2, weights=distance........
# [CV 4/5; 16/64] END leaf_size=5, n_neighbors=10, p=2, weights=distance;, score=0.551 total time=   0.0s
# [CV 5/5; 16/64] START leaf_size=5, n_neighbors=10, p=2, weights=distance........
# [CV 5/5; 16/64] END leaf_size=5, n_neighbors=10, p=2, weights=distance;, score=0.585 total time=   0.0s
# [CV 1/5; 17/64] START leaf_size=10, n_neighbors=1, p=1, weights=uniform.........
# [CV 1/5; 17/64] END leaf_size=10, n_neighbors=1, p=1, weights=uniform;, score=0.593 total time=   0.0s
# [CV 2/5; 17/64] START leaf_size=10, n_neighbors=1, p=1, weights=uniform.........
# [CV 2/5; 17/64] END leaf_size=10, n_neighbors=1, p=1, weights=uniform;, score=0.582 total time=   0.0s
# [CV 3/5; 17/64] START leaf_size=10, n_neighbors=1, p=1, weights=uniform.........
# [CV 3/5; 17/64] END leaf_size=10, n_neighbors=1, p=1, weights=uniform;, score=0.607 total time=   0.0s
# [CV 4/5; 17/64] START leaf_size=10, n_neighbors=1, p=1, weights=uniform.........
# [CV 4/5; 17/64] END leaf_size=10, n_neighbors=1, p=1, weights=uniform;, score=0.603 total time=   0.0s
# [CV 5/5; 17/64] START leaf_size=10, n_neighbors=1, p=1, weights=uniform.........
# [CV 5/5; 17/64] END leaf_size=10, n_neighbors=1, p=1, weights=uniform;, score=0.606 total time=   0.0s
# [CV 1/5; 18/64] START leaf_size=10, n_neighbors=1, p=1, weights=distance........
# [CV 1/5; 18/64] END leaf_size=10, n_neighbors=1, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 18/64] START leaf_size=10, n_neighbors=1, p=1, weights=distance........
# [CV 2/5; 18/64] END leaf_size=10, n_neighbors=1, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 18/64] START leaf_size=10, n_neighbors=1, p=1, weights=distance........
# [CV 3/5; 18/64] END leaf_size=10, n_neighbors=1, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 18/64] START leaf_size=10, n_neighbors=1, p=1, weights=distance........
# [CV 4/5; 18/64] END leaf_size=10, n_neighbors=1, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 18/64] START leaf_size=10, n_neighbors=1, p=1, weights=distance........
# [CV 5/5; 18/64] END leaf_size=10, n_neighbors=1, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 19/64] START leaf_size=10, n_neighbors=1, p=2, weights=uniform.........
# [CV 1/5; 19/64] END leaf_size=10, n_neighbors=1, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 2/5; 19/64] START leaf_size=10, n_neighbors=1, p=2, weights=uniform.........
# [CV 2/5; 19/64] END leaf_size=10, n_neighbors=1, p=2, weights=uniform;, score=0.566 total time=   0.0s
# [CV 3/5; 19/64] START leaf_size=10, n_neighbors=1, p=2, weights=uniform.........
# [CV 3/5; 19/64] END leaf_size=10, n_neighbors=1, p=2, weights=uniform;, score=0.587 total time=   0.0s
# [CV 4/5; 19/64] START leaf_size=10, n_neighbors=1, p=2, weights=uniform.........
# [CV 4/5; 19/64] END leaf_size=10, n_neighbors=1, p=2, weights=uniform;, score=0.582 total time=   0.0s
# [CV 5/5; 19/64] START leaf_size=10, n_neighbors=1, p=2, weights=uniform.........
# [CV 5/5; 19/64] END leaf_size=10, n_neighbors=1, p=2, weights=uniform;, score=0.593 total time=   0.0s
# [CV 1/5; 20/64] START leaf_size=10, n_neighbors=1, p=2, weights=distance........
# [CV 1/5; 20/64] END leaf_size=10, n_neighbors=1, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 20/64] START leaf_size=10, n_neighbors=1, p=2, weights=distance........
# [CV 2/5; 20/64] END leaf_size=10, n_neighbors=1, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 20/64] START leaf_size=10, n_neighbors=1, p=2, weights=distance........
# [CV 3/5; 20/64] END leaf_size=10, n_neighbors=1, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 20/64] START leaf_size=10, n_neighbors=1, p=2, weights=distance........
# [CV 4/5; 20/64] END leaf_size=10, n_neighbors=1, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 20/64] START leaf_size=10, n_neighbors=1, p=2, weights=distance........
# [CV 5/5; 20/64] END leaf_size=10, n_neighbors=1, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 21/64] START leaf_size=10, n_neighbors=2, p=1, weights=uniform.........
# [CV 1/5; 21/64] END leaf_size=10, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 2/5; 21/64] START leaf_size=10, n_neighbors=2, p=1, weights=uniform.........
# [CV 2/5; 21/64] END leaf_size=10, n_neighbors=2, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 3/5; 21/64] START leaf_size=10, n_neighbors=2, p=1, weights=uniform.........
# [CV 3/5; 21/64] END leaf_size=10, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 4/5; 21/64] START leaf_size=10, n_neighbors=2, p=1, weights=uniform.........
# [CV 4/5; 21/64] END leaf_size=10, n_neighbors=2, p=1, weights=uniform;, score=0.566 total time=   0.0s
# [CV 5/5; 21/64] START leaf_size=10, n_neighbors=2, p=1, weights=uniform.........
# [CV 5/5; 21/64] END leaf_size=10, n_neighbors=2, p=1, weights=uniform;, score=0.589 total time=   0.0s
# [CV 1/5; 22/64] START leaf_size=10, n_neighbors=2, p=1, weights=distance........
# [CV 1/5; 22/64] END leaf_size=10, n_neighbors=2, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 22/64] START leaf_size=10, n_neighbors=2, p=1, weights=distance........
# [CV 2/5; 22/64] END leaf_size=10, n_neighbors=2, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 22/64] START leaf_size=10, n_neighbors=2, p=1, weights=distance........
# [CV 3/5; 22/64] END leaf_size=10, n_neighbors=2, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 22/64] START leaf_size=10, n_neighbors=2, p=1, weights=distance........
# [CV 4/5; 22/64] END leaf_size=10, n_neighbors=2, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 22/64] START leaf_size=10, n_neighbors=2, p=1, weights=distance........
# [CV 5/5; 22/64] END leaf_size=10, n_neighbors=2, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 23/64] START leaf_size=10, n_neighbors=2, p=2, weights=uniform.........
# [CV 1/5; 23/64] END leaf_size=10, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 2/5; 23/64] START leaf_size=10, n_neighbors=2, p=2, weights=uniform.........
# [CV 2/5; 23/64] END leaf_size=10, n_neighbors=2, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 23/64] START leaf_size=10, n_neighbors=2, p=2, weights=uniform.........
# [CV 3/5; 23/64] END leaf_size=10, n_neighbors=2, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 23/64] START leaf_size=10, n_neighbors=2, p=2, weights=uniform.........
# [CV 4/5; 23/64] END leaf_size=10, n_neighbors=2, p=2, weights=uniform;, score=0.551 total time=   0.0s
# [CV 5/5; 23/64] START leaf_size=10, n_neighbors=2, p=2, weights=uniform.........
# [CV 5/5; 23/64] END leaf_size=10, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 1/5; 24/64] START leaf_size=10, n_neighbors=2, p=2, weights=distance........
# [CV 1/5; 24/64] END leaf_size=10, n_neighbors=2, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 24/64] START leaf_size=10, n_neighbors=2, p=2, weights=distance........
# [CV 2/5; 24/64] END leaf_size=10, n_neighbors=2, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 24/64] START leaf_size=10, n_neighbors=2, p=2, weights=distance........
# [CV 3/5; 24/64] END leaf_size=10, n_neighbors=2, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 24/64] START leaf_size=10, n_neighbors=2, p=2, weights=distance........
# [CV 4/5; 24/64] END leaf_size=10, n_neighbors=2, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 24/64] START leaf_size=10, n_neighbors=2, p=2, weights=distance........
# [CV 5/5; 24/64] END leaf_size=10, n_neighbors=2, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 25/64] START leaf_size=10, n_neighbors=5, p=1, weights=uniform.........
# [CV 1/5; 25/64] END leaf_size=10, n_neighbors=5, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 2/5; 25/64] START leaf_size=10, n_neighbors=5, p=1, weights=uniform.........
# [CV 2/5; 25/64] END leaf_size=10, n_neighbors=5, p=1, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 25/64] START leaf_size=10, n_neighbors=5, p=1, weights=uniform.........
# [CV 3/5; 25/64] END leaf_size=10, n_neighbors=5, p=1, weights=uniform;, score=0.581 total time=   0.0s
# [CV 4/5; 25/64] START leaf_size=10, n_neighbors=5, p=1, weights=uniform.........
# [CV 4/5; 25/64] END leaf_size=10, n_neighbors=5, p=1, weights=uniform;, score=0.533 total time=   0.0s
# [CV 5/5; 25/64] START leaf_size=10, n_neighbors=5, p=1, weights=uniform.........
# [CV 5/5; 25/64] END leaf_size=10, n_neighbors=5, p=1, weights=uniform;, score=0.576 total time=   0.0s
# [CV 1/5; 26/64] START leaf_size=10, n_neighbors=5, p=1, weights=distance........
# [CV 1/5; 26/64] END leaf_size=10, n_neighbors=5, p=1, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 26/64] START leaf_size=10, n_neighbors=5, p=1, weights=distance........
# [CV 2/5; 26/64] END leaf_size=10, n_neighbors=5, p=1, weights=distance;, score=0.572 total time=   0.0s
# [CV 3/5; 26/64] START leaf_size=10, n_neighbors=5, p=1, weights=distance........
# [CV 3/5; 26/64] END leaf_size=10, n_neighbors=5, p=1, weights=distance;, score=0.605 total time=   0.0s
# [CV 4/5; 26/64] START leaf_size=10, n_neighbors=5, p=1, weights=distance........
# [CV 4/5; 26/64] END leaf_size=10, n_neighbors=5, p=1, weights=distance;, score=0.564 total time=   0.0s
# [CV 5/5; 26/64] START leaf_size=10, n_neighbors=5, p=1, weights=distance........
# [CV 5/5; 26/64] END leaf_size=10, n_neighbors=5, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 1/5; 27/64] START leaf_size=10, n_neighbors=5, p=2, weights=uniform.........
# [CV 1/5; 27/64] END leaf_size=10, n_neighbors=5, p=2, weights=uniform;, score=0.543 total time=   0.0s
# [CV 2/5; 27/64] START leaf_size=10, n_neighbors=5, p=2, weights=uniform.........
# [CV 2/5; 27/64] END leaf_size=10, n_neighbors=5, p=2, weights=uniform;, score=0.534 total time=   0.0s
# [CV 3/5; 27/64] START leaf_size=10, n_neighbors=5, p=2, weights=uniform.........
# [CV 3/5; 27/64] END leaf_size=10, n_neighbors=5, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 27/64] START leaf_size=10, n_neighbors=5, p=2, weights=uniform.........
# [CV 4/5; 27/64] END leaf_size=10, n_neighbors=5, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 5/5; 27/64] START leaf_size=10, n_neighbors=5, p=2, weights=uniform.........
# [CV 5/5; 27/64] END leaf_size=10, n_neighbors=5, p=2, weights=uniform;, score=0.568 total time=   0.0s
# [CV 1/5; 28/64] START leaf_size=10, n_neighbors=5, p=2, weights=distance........
# [CV 1/5; 28/64] END leaf_size=10, n_neighbors=5, p=2, weights=distance;, score=0.555 total time=   0.0s
# [CV 2/5; 28/64] START leaf_size=10, n_neighbors=5, p=2, weights=distance........
# [CV 2/5; 28/64] END leaf_size=10, n_neighbors=5, p=2, weights=distance;, score=0.554 total time=   0.0s
# [CV 3/5; 28/64] START leaf_size=10, n_neighbors=5, p=2, weights=distance........
# [CV 3/5; 28/64] END leaf_size=10, n_neighbors=5, p=2, weights=distance;, score=0.575 total time=   0.0s
# [CV 4/5; 28/64] START leaf_size=10, n_neighbors=5, p=2, weights=distance........
# [CV 4/5; 28/64] END leaf_size=10, n_neighbors=5, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 5/5; 28/64] START leaf_size=10, n_neighbors=5, p=2, weights=distance........
# [CV 5/5; 28/64] END leaf_size=10, n_neighbors=5, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 1/5; 29/64] START leaf_size=10, n_neighbors=10, p=1, weights=uniform........
# [CV 1/5; 29/64] END leaf_size=10, n_neighbors=10, p=1, weights=uniform;, score=0.535 total time=   0.0s
# [CV 2/5; 29/64] START leaf_size=10, n_neighbors=10, p=1, weights=uniform........
# [CV 2/5; 29/64] END leaf_size=10, n_neighbors=10, p=1, weights=uniform;, score=0.524 total time=   0.0s
# [CV 3/5; 29/64] START leaf_size=10, n_neighbors=10, p=1, weights=uniform........
# [CV 3/5; 29/64] END leaf_size=10, n_neighbors=10, p=1, weights=uniform;, score=0.548 total time=   0.0s
# [CV 4/5; 29/64] START leaf_size=10, n_neighbors=10, p=1, weights=uniform........
# [CV 4/5; 29/64] END leaf_size=10, n_neighbors=10, p=1, weights=uniform;, score=0.541 total time=   0.0s
# [CV 5/5; 29/64] START leaf_size=10, n_neighbors=10, p=1, weights=uniform........
# [CV 5/5; 29/64] END leaf_size=10, n_neighbors=10, p=1, weights=uniform;, score=0.543 total time=   0.0s
# [CV 1/5; 30/64] START leaf_size=10, n_neighbors=10, p=1, weights=distance.......
# [CV 1/5; 30/64] END leaf_size=10, n_neighbors=10, p=1, weights=distance;, score=0.571 total time=   0.0s
# [CV 2/5; 30/64] START leaf_size=10, n_neighbors=10, p=1, weights=distance.......
# [CV 2/5; 30/64] END leaf_size=10, n_neighbors=10, p=1, weights=distance;, score=0.555 total time=   0.0s
# [CV 3/5; 30/64] START leaf_size=10, n_neighbors=10, p=1, weights=distance.......
# [CV 3/5; 30/64] END leaf_size=10, n_neighbors=10, p=1, weights=distance;, score=0.584 total time=   0.0s
# [CV 4/5; 30/64] START leaf_size=10, n_neighbors=10, p=1, weights=distance.......
# [CV 4/5; 30/64] END leaf_size=10, n_neighbors=10, p=1, weights=distance;, score=0.574 total time=   0.0s
# [CV 5/5; 30/64] START leaf_size=10, n_neighbors=10, p=1, weights=distance.......
# [CV 5/5; 30/64] END leaf_size=10, n_neighbors=10, p=1, weights=distance;, score=0.576 total time=   0.0s
# [CV 1/5; 31/64] START leaf_size=10, n_neighbors=10, p=2, weights=uniform........
# [CV 1/5; 31/64] END leaf_size=10, n_neighbors=10, p=2, weights=uniform;, score=0.538 total time=   0.0s
# [CV 2/5; 31/64] START leaf_size=10, n_neighbors=10, p=2, weights=uniform........
# [CV 2/5; 31/64] END leaf_size=10, n_neighbors=10, p=2, weights=uniform;, score=0.542 total time=   0.0s
# [CV 3/5; 31/64] START leaf_size=10, n_neighbors=10, p=2, weights=uniform........
# [CV 3/5; 31/64] END leaf_size=10, n_neighbors=10, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 4/5; 31/64] START leaf_size=10, n_neighbors=10, p=2, weights=uniform........
# [CV 4/5; 31/64] END leaf_size=10, n_neighbors=10, p=2, weights=uniform;, score=0.535 total time=   0.0s
# [CV 5/5; 31/64] START leaf_size=10, n_neighbors=10, p=2, weights=uniform........
# [CV 5/5; 31/64] END leaf_size=10, n_neighbors=10, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 1/5; 32/64] START leaf_size=10, n_neighbors=10, p=2, weights=distance.......
# [CV 1/5; 32/64] END leaf_size=10, n_neighbors=10, p=2, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 32/64] START leaf_size=10, n_neighbors=10, p=2, weights=distance.......
# [CV 2/5; 32/64] END leaf_size=10, n_neighbors=10, p=2, weights=distance;, score=0.552 total time=   0.0s
# [CV 3/5; 32/64] START leaf_size=10, n_neighbors=10, p=2, weights=distance.......
# [CV 3/5; 32/64] END leaf_size=10, n_neighbors=10, p=2, weights=distance;, score=0.577 total time=   0.0s
# [CV 4/5; 32/64] START leaf_size=10, n_neighbors=10, p=2, weights=distance.......
# [CV 4/5; 32/64] END leaf_size=10, n_neighbors=10, p=2, weights=distance;, score=0.551 total time=   0.0s
# [CV 5/5; 32/64] START leaf_size=10, n_neighbors=10, p=2, weights=distance.......
# [CV 5/5; 32/64] END leaf_size=10, n_neighbors=10, p=2, weights=distance;, score=0.585 total time=   0.0s
# [CV 1/5; 33/64] START leaf_size=20, n_neighbors=1, p=1, weights=uniform.........
# [CV 1/5; 33/64] END leaf_size=20, n_neighbors=1, p=1, weights=uniform;, score=0.593 total time=   0.0s
# [CV 2/5; 33/64] START leaf_size=20, n_neighbors=1, p=1, weights=uniform.........
# [CV 2/5; 33/64] END leaf_size=20, n_neighbors=1, p=1, weights=uniform;, score=0.582 total time=   0.0s
# [CV 3/5; 33/64] START leaf_size=20, n_neighbors=1, p=1, weights=uniform.........
# [CV 3/5; 33/64] END leaf_size=20, n_neighbors=1, p=1, weights=uniform;, score=0.607 total time=   0.0s
# [CV 4/5; 33/64] START leaf_size=20, n_neighbors=1, p=1, weights=uniform.........
# [CV 4/5; 33/64] END leaf_size=20, n_neighbors=1, p=1, weights=uniform;, score=0.603 total time=   0.0s
# [CV 5/5; 33/64] START leaf_size=20, n_neighbors=1, p=1, weights=uniform.........
# [CV 5/5; 33/64] END leaf_size=20, n_neighbors=1, p=1, weights=uniform;, score=0.606 total time=   0.0s
# [CV 1/5; 34/64] START leaf_size=20, n_neighbors=1, p=1, weights=distance........
# [CV 1/5; 34/64] END leaf_size=20, n_neighbors=1, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 34/64] START leaf_size=20, n_neighbors=1, p=1, weights=distance........
# [CV 2/5; 34/64] END leaf_size=20, n_neighbors=1, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 34/64] START leaf_size=20, n_neighbors=1, p=1, weights=distance........
# [CV 3/5; 34/64] END leaf_size=20, n_neighbors=1, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 34/64] START leaf_size=20, n_neighbors=1, p=1, weights=distance........
# [CV 4/5; 34/64] END leaf_size=20, n_neighbors=1, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 34/64] START leaf_size=20, n_neighbors=1, p=1, weights=distance........
# [CV 5/5; 34/64] END leaf_size=20, n_neighbors=1, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 35/64] START leaf_size=20, n_neighbors=1, p=2, weights=uniform.........
# [CV 1/5; 35/64] END leaf_size=20, n_neighbors=1, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 2/5; 35/64] START leaf_size=20, n_neighbors=1, p=2, weights=uniform.........
# [CV 2/5; 35/64] END leaf_size=20, n_neighbors=1, p=2, weights=uniform;, score=0.566 total time=   0.0s
# [CV 3/5; 35/64] START leaf_size=20, n_neighbors=1, p=2, weights=uniform.........
# [CV 3/5; 35/64] END leaf_size=20, n_neighbors=1, p=2, weights=uniform;, score=0.587 total time=   0.0s
# [CV 4/5; 35/64] START leaf_size=20, n_neighbors=1, p=2, weights=uniform.........
# [CV 4/5; 35/64] END leaf_size=20, n_neighbors=1, p=2, weights=uniform;, score=0.582 total time=   0.0s
# [CV 5/5; 35/64] START leaf_size=20, n_neighbors=1, p=2, weights=uniform.........
# [CV 5/5; 35/64] END leaf_size=20, n_neighbors=1, p=2, weights=uniform;, score=0.593 total time=   0.0s
# [CV 1/5; 36/64] START leaf_size=20, n_neighbors=1, p=2, weights=distance........
# [CV 1/5; 36/64] END leaf_size=20, n_neighbors=1, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 36/64] START leaf_size=20, n_neighbors=1, p=2, weights=distance........
# [CV 2/5; 36/64] END leaf_size=20, n_neighbors=1, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 36/64] START leaf_size=20, n_neighbors=1, p=2, weights=distance........
# [CV 3/5; 36/64] END leaf_size=20, n_neighbors=1, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 36/64] START leaf_size=20, n_neighbors=1, p=2, weights=distance........
# [CV 4/5; 36/64] END leaf_size=20, n_neighbors=1, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 36/64] START leaf_size=20, n_neighbors=1, p=2, weights=distance........
# [CV 5/5; 36/64] END leaf_size=20, n_neighbors=1, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 37/64] START leaf_size=20, n_neighbors=2, p=1, weights=uniform.........
# [CV 1/5; 37/64] END leaf_size=20, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 2/5; 37/64] START leaf_size=20, n_neighbors=2, p=1, weights=uniform.........
# [CV 2/5; 37/64] END leaf_size=20, n_neighbors=2, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 3/5; 37/64] START leaf_size=20, n_neighbors=2, p=1, weights=uniform.........
# [CV 3/5; 37/64] END leaf_size=20, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 4/5; 37/64] START leaf_size=20, n_neighbors=2, p=1, weights=uniform.........
# [CV 4/5; 37/64] END leaf_size=20, n_neighbors=2, p=1, weights=uniform;, score=0.566 total time=   0.0s
# [CV 5/5; 37/64] START leaf_size=20, n_neighbors=2, p=1, weights=uniform.........
# [CV 5/5; 37/64] END leaf_size=20, n_neighbors=2, p=1, weights=uniform;, score=0.589 total time=   0.0s
# [CV 1/5; 38/64] START leaf_size=20, n_neighbors=2, p=1, weights=distance........
# [CV 1/5; 38/64] END leaf_size=20, n_neighbors=2, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 38/64] START leaf_size=20, n_neighbors=2, p=1, weights=distance........
# [CV 2/5; 38/64] END leaf_size=20, n_neighbors=2, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 38/64] START leaf_size=20, n_neighbors=2, p=1, weights=distance........
# [CV 3/5; 38/64] END leaf_size=20, n_neighbors=2, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 38/64] START leaf_size=20, n_neighbors=2, p=1, weights=distance........
# [CV 4/5; 38/64] END leaf_size=20, n_neighbors=2, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 38/64] START leaf_size=20, n_neighbors=2, p=1, weights=distance........
# [CV 5/5; 38/64] END leaf_size=20, n_neighbors=2, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 39/64] START leaf_size=20, n_neighbors=2, p=2, weights=uniform.........
# [CV 1/5; 39/64] END leaf_size=20, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 2/5; 39/64] START leaf_size=20, n_neighbors=2, p=2, weights=uniform.........
# [CV 2/5; 39/64] END leaf_size=20, n_neighbors=2, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 39/64] START leaf_size=20, n_neighbors=2, p=2, weights=uniform.........
# [CV 3/5; 39/64] END leaf_size=20, n_neighbors=2, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 39/64] START leaf_size=20, n_neighbors=2, p=2, weights=uniform.........
# [CV 4/5; 39/64] END leaf_size=20, n_neighbors=2, p=2, weights=uniform;, score=0.551 total time=   0.0s
# [CV 5/5; 39/64] START leaf_size=20, n_neighbors=2, p=2, weights=uniform.........
# [CV 5/5; 39/64] END leaf_size=20, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 1/5; 40/64] START leaf_size=20, n_neighbors=2, p=2, weights=distance........
# [CV 1/5; 40/64] END leaf_size=20, n_neighbors=2, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 40/64] START leaf_size=20, n_neighbors=2, p=2, weights=distance........
# [CV 2/5; 40/64] END leaf_size=20, n_neighbors=2, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 40/64] START leaf_size=20, n_neighbors=2, p=2, weights=distance........
# [CV 3/5; 40/64] END leaf_size=20, n_neighbors=2, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 40/64] START leaf_size=20, n_neighbors=2, p=2, weights=distance........
# [CV 4/5; 40/64] END leaf_size=20, n_neighbors=2, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 40/64] START leaf_size=20, n_neighbors=2, p=2, weights=distance........
# [CV 5/5; 40/64] END leaf_size=20, n_neighbors=2, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 41/64] START leaf_size=20, n_neighbors=5, p=1, weights=uniform.........
# [CV 1/5; 41/64] END leaf_size=20, n_neighbors=5, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 2/5; 41/64] START leaf_size=20, n_neighbors=5, p=1, weights=uniform.........
# [CV 2/5; 41/64] END leaf_size=20, n_neighbors=5, p=1, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 41/64] START leaf_size=20, n_neighbors=5, p=1, weights=uniform.........
# [CV 3/5; 41/64] END leaf_size=20, n_neighbors=5, p=1, weights=uniform;, score=0.581 total time=   0.0s
# [CV 4/5; 41/64] START leaf_size=20, n_neighbors=5, p=1, weights=uniform.........
# [CV 4/5; 41/64] END leaf_size=20, n_neighbors=5, p=1, weights=uniform;, score=0.533 total time=   0.0s
# [CV 5/5; 41/64] START leaf_size=20, n_neighbors=5, p=1, weights=uniform.........
# [CV 5/5; 41/64] END leaf_size=20, n_neighbors=5, p=1, weights=uniform;, score=0.576 total time=   0.0s
# [CV 1/5; 42/64] START leaf_size=20, n_neighbors=5, p=1, weights=distance........
# [CV 1/5; 42/64] END leaf_size=20, n_neighbors=5, p=1, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 42/64] START leaf_size=20, n_neighbors=5, p=1, weights=distance........
# [CV 2/5; 42/64] END leaf_size=20, n_neighbors=5, p=1, weights=distance;, score=0.572 total time=   0.0s
# [CV 3/5; 42/64] START leaf_size=20, n_neighbors=5, p=1, weights=distance........
# [CV 3/5; 42/64] END leaf_size=20, n_neighbors=5, p=1, weights=distance;, score=0.605 total time=   0.0s
# [CV 4/5; 42/64] START leaf_size=20, n_neighbors=5, p=1, weights=distance........
# [CV 4/5; 42/64] END leaf_size=20, n_neighbors=5, p=1, weights=distance;, score=0.564 total time=   0.0s
# [CV 5/5; 42/64] START leaf_size=20, n_neighbors=5, p=1, weights=distance........
# [CV 5/5; 42/64] END leaf_size=20, n_neighbors=5, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 1/5; 43/64] START leaf_size=20, n_neighbors=5, p=2, weights=uniform.........
# [CV 1/5; 43/64] END leaf_size=20, n_neighbors=5, p=2, weights=uniform;, score=0.543 total time=   0.0s
# [CV 2/5; 43/64] START leaf_size=20, n_neighbors=5, p=2, weights=uniform.........
# [CV 2/5; 43/64] END leaf_size=20, n_neighbors=5, p=2, weights=uniform;, score=0.534 total time=   0.0s
# [CV 3/5; 43/64] START leaf_size=20, n_neighbors=5, p=2, weights=uniform.........
# [CV 3/5; 43/64] END leaf_size=20, n_neighbors=5, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 43/64] START leaf_size=20, n_neighbors=5, p=2, weights=uniform.........
# [CV 4/5; 43/64] END leaf_size=20, n_neighbors=5, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 5/5; 43/64] START leaf_size=20, n_neighbors=5, p=2, weights=uniform.........
# [CV 5/5; 43/64] END leaf_size=20, n_neighbors=5, p=2, weights=uniform;, score=0.568 total time=   0.0s
# [CV 1/5; 44/64] START leaf_size=20, n_neighbors=5, p=2, weights=distance........
# [CV 1/5; 44/64] END leaf_size=20, n_neighbors=5, p=2, weights=distance;, score=0.555 total time=   0.0s
# [CV 2/5; 44/64] START leaf_size=20, n_neighbors=5, p=2, weights=distance........
# [CV 2/5; 44/64] END leaf_size=20, n_neighbors=5, p=2, weights=distance;, score=0.554 total time=   0.0s
# [CV 3/5; 44/64] START leaf_size=20, n_neighbors=5, p=2, weights=distance........
# [CV 3/5; 44/64] END leaf_size=20, n_neighbors=5, p=2, weights=distance;, score=0.575 total time=   0.0s
# [CV 4/5; 44/64] START leaf_size=20, n_neighbors=5, p=2, weights=distance........
# [CV 4/5; 44/64] END leaf_size=20, n_neighbors=5, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 5/5; 44/64] START leaf_size=20, n_neighbors=5, p=2, weights=distance........
# [CV 5/5; 44/64] END leaf_size=20, n_neighbors=5, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 1/5; 45/64] START leaf_size=20, n_neighbors=10, p=1, weights=uniform........
# [CV 1/5; 45/64] END leaf_size=20, n_neighbors=10, p=1, weights=uniform;, score=0.535 total time=   0.0s
# [CV 2/5; 45/64] START leaf_size=20, n_neighbors=10, p=1, weights=uniform........
# [CV 2/5; 45/64] END leaf_size=20, n_neighbors=10, p=1, weights=uniform;, score=0.524 total time=   0.0s
# [CV 3/5; 45/64] START leaf_size=20, n_neighbors=10, p=1, weights=uniform........
# [CV 3/5; 45/64] END leaf_size=20, n_neighbors=10, p=1, weights=uniform;, score=0.548 total time=   0.0s
# [CV 4/5; 45/64] START leaf_size=20, n_neighbors=10, p=1, weights=uniform........
# [CV 4/5; 45/64] END leaf_size=20, n_neighbors=10, p=1, weights=uniform;, score=0.541 total time=   0.0s
# [CV 5/5; 45/64] START leaf_size=20, n_neighbors=10, p=1, weights=uniform........
# [CV 5/5; 45/64] END leaf_size=20, n_neighbors=10, p=1, weights=uniform;, score=0.543 total time=   0.0s
# [CV 1/5; 46/64] START leaf_size=20, n_neighbors=10, p=1, weights=distance.......
# [CV 1/5; 46/64] END leaf_size=20, n_neighbors=10, p=1, weights=distance;, score=0.571 total time=   0.0s
# [CV 2/5; 46/64] START leaf_size=20, n_neighbors=10, p=1, weights=distance.......
# [CV 2/5; 46/64] END leaf_size=20, n_neighbors=10, p=1, weights=distance;, score=0.555 total time=   0.0s
# [CV 3/5; 46/64] START leaf_size=20, n_neighbors=10, p=1, weights=distance.......
# [CV 3/5; 46/64] END leaf_size=20, n_neighbors=10, p=1, weights=distance;, score=0.584 total time=   0.0s
# [CV 4/5; 46/64] START leaf_size=20, n_neighbors=10, p=1, weights=distance.......
# [CV 4/5; 46/64] END leaf_size=20, n_neighbors=10, p=1, weights=distance;, score=0.574 total time=   0.0s
# [CV 5/5; 46/64] START leaf_size=20, n_neighbors=10, p=1, weights=distance.......
# [CV 5/5; 46/64] END leaf_size=20, n_neighbors=10, p=1, weights=distance;, score=0.576 total time=   0.0s
# [CV 1/5; 47/64] START leaf_size=20, n_neighbors=10, p=2, weights=uniform........
# [CV 1/5; 47/64] END leaf_size=20, n_neighbors=10, p=2, weights=uniform;, score=0.538 total time=   0.0s
# [CV 2/5; 47/64] START leaf_size=20, n_neighbors=10, p=2, weights=uniform........
# [CV 2/5; 47/64] END leaf_size=20, n_neighbors=10, p=2, weights=uniform;, score=0.542 total time=   0.0s
# [CV 3/5; 47/64] START leaf_size=20, n_neighbors=10, p=2, weights=uniform........
# [CV 3/5; 47/64] END leaf_size=20, n_neighbors=10, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 4/5; 47/64] START leaf_size=20, n_neighbors=10, p=2, weights=uniform........
# [CV 4/5; 47/64] END leaf_size=20, n_neighbors=10, p=2, weights=uniform;, score=0.535 total time=   0.0s
# [CV 5/5; 47/64] START leaf_size=20, n_neighbors=10, p=2, weights=uniform........
# [CV 5/5; 47/64] END leaf_size=20, n_neighbors=10, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 1/5; 48/64] START leaf_size=20, n_neighbors=10, p=2, weights=distance.......
# [CV 1/5; 48/64] END leaf_size=20, n_neighbors=10, p=2, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 48/64] START leaf_size=20, n_neighbors=10, p=2, weights=distance.......
# [CV 2/5; 48/64] END leaf_size=20, n_neighbors=10, p=2, weights=distance;, score=0.552 total time=   0.0s
# [CV 3/5; 48/64] START leaf_size=20, n_neighbors=10, p=2, weights=distance.......
# [CV 3/5; 48/64] END leaf_size=20, n_neighbors=10, p=2, weights=distance;, score=0.577 total time=   0.0s
# [CV 4/5; 48/64] START leaf_size=20, n_neighbors=10, p=2, weights=distance.......
# [CV 4/5; 48/64] END leaf_size=20, n_neighbors=10, p=2, weights=distance;, score=0.551 total time=   0.0s
# [CV 5/5; 48/64] START leaf_size=20, n_neighbors=10, p=2, weights=distance.......
# [CV 5/5; 48/64] END leaf_size=20, n_neighbors=10, p=2, weights=distance;, score=0.585 total time=   0.0s
# [CV 1/5; 49/64] START leaf_size=30, n_neighbors=1, p=1, weights=uniform.........
# [CV 1/5; 49/64] END leaf_size=30, n_neighbors=1, p=1, weights=uniform;, score=0.593 total time=   0.0s
# [CV 2/5; 49/64] START leaf_size=30, n_neighbors=1, p=1, weights=uniform.........
# [CV 2/5; 49/64] END leaf_size=30, n_neighbors=1, p=1, weights=uniform;, score=0.582 total time=   0.0s
# [CV 3/5; 49/64] START leaf_size=30, n_neighbors=1, p=1, weights=uniform.........
# [CV 3/5; 49/64] END leaf_size=30, n_neighbors=1, p=1, weights=uniform;, score=0.607 total time=   0.0s
# [CV 4/5; 49/64] START leaf_size=30, n_neighbors=1, p=1, weights=uniform.........
# [CV 4/5; 49/64] END leaf_size=30, n_neighbors=1, p=1, weights=uniform;, score=0.603 total time=   0.0s
# [CV 5/5; 49/64] START leaf_size=30, n_neighbors=1, p=1, weights=uniform.........
# [CV 5/5; 49/64] END leaf_size=30, n_neighbors=1, p=1, weights=uniform;, score=0.606 total time=   0.0s
# [CV 1/5; 50/64] START leaf_size=30, n_neighbors=1, p=1, weights=distance........
# [CV 1/5; 50/64] END leaf_size=30, n_neighbors=1, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 50/64] START leaf_size=30, n_neighbors=1, p=1, weights=distance........
# [CV 2/5; 50/64] END leaf_size=30, n_neighbors=1, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 50/64] START leaf_size=30, n_neighbors=1, p=1, weights=distance........
# [CV 3/5; 50/64] END leaf_size=30, n_neighbors=1, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 50/64] START leaf_size=30, n_neighbors=1, p=1, weights=distance........
# [CV 4/5; 50/64] END leaf_size=30, n_neighbors=1, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 50/64] START leaf_size=30, n_neighbors=1, p=1, weights=distance........
# [CV 5/5; 50/64] END leaf_size=30, n_neighbors=1, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 51/64] START leaf_size=30, n_neighbors=1, p=2, weights=uniform.........
# [CV 1/5; 51/64] END leaf_size=30, n_neighbors=1, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 2/5; 51/64] START leaf_size=30, n_neighbors=1, p=2, weights=uniform.........
# [CV 2/5; 51/64] END leaf_size=30, n_neighbors=1, p=2, weights=uniform;, score=0.566 total time=   0.0s
# [CV 3/5; 51/64] START leaf_size=30, n_neighbors=1, p=2, weights=uniform.........
# [CV 3/5; 51/64] END leaf_size=30, n_neighbors=1, p=2, weights=uniform;, score=0.587 total time=   0.0s
# [CV 4/5; 51/64] START leaf_size=30, n_neighbors=1, p=2, weights=uniform.........
# [CV 4/5; 51/64] END leaf_size=30, n_neighbors=1, p=2, weights=uniform;, score=0.582 total time=   0.0s
# [CV 5/5; 51/64] START leaf_size=30, n_neighbors=1, p=2, weights=uniform.........
# [CV 5/5; 51/64] END leaf_size=30, n_neighbors=1, p=2, weights=uniform;, score=0.593 total time=   0.0s
# [CV 1/5; 52/64] START leaf_size=30, n_neighbors=1, p=2, weights=distance........
# [CV 1/5; 52/64] END leaf_size=30, n_neighbors=1, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 52/64] START leaf_size=30, n_neighbors=1, p=2, weights=distance........
# [CV 2/5; 52/64] END leaf_size=30, n_neighbors=1, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 52/64] START leaf_size=30, n_neighbors=1, p=2, weights=distance........
# [CV 3/5; 52/64] END leaf_size=30, n_neighbors=1, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 52/64] START leaf_size=30, n_neighbors=1, p=2, weights=distance........
# [CV 4/5; 52/64] END leaf_size=30, n_neighbors=1, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 52/64] START leaf_size=30, n_neighbors=1, p=2, weights=distance........
# [CV 5/5; 52/64] END leaf_size=30, n_neighbors=1, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 53/64] START leaf_size=30, n_neighbors=2, p=1, weights=uniform.........
# [CV 1/5; 53/64] END leaf_size=30, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 2/5; 53/64] START leaf_size=30, n_neighbors=2, p=1, weights=uniform.........
# [CV 2/5; 53/64] END leaf_size=30, n_neighbors=2, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 3/5; 53/64] START leaf_size=30, n_neighbors=2, p=1, weights=uniform.........
# [CV 3/5; 53/64] END leaf_size=30, n_neighbors=2, p=1, weights=uniform;, score=0.574 total time=   0.0s
# [CV 4/5; 53/64] START leaf_size=30, n_neighbors=2, p=1, weights=uniform.........
# [CV 4/5; 53/64] END leaf_size=30, n_neighbors=2, p=1, weights=uniform;, score=0.566 total time=   0.0s
# [CV 5/5; 53/64] START leaf_size=30, n_neighbors=2, p=1, weights=uniform.........
# [CV 5/5; 53/64] END leaf_size=30, n_neighbors=2, p=1, weights=uniform;, score=0.589 total time=   0.0s
# [CV 1/5; 54/64] START leaf_size=30, n_neighbors=2, p=1, weights=distance........
# [CV 1/5; 54/64] END leaf_size=30, n_neighbors=2, p=1, weights=distance;, score=0.593 total time=   0.0s
# [CV 2/5; 54/64] START leaf_size=30, n_neighbors=2, p=1, weights=distance........
# [CV 2/5; 54/64] END leaf_size=30, n_neighbors=2, p=1, weights=distance;, score=0.582 total time=   0.0s
# [CV 3/5; 54/64] START leaf_size=30, n_neighbors=2, p=1, weights=distance........
# [CV 3/5; 54/64] END leaf_size=30, n_neighbors=2, p=1, weights=distance;, score=0.607 total time=   0.0s
# [CV 4/5; 54/64] START leaf_size=30, n_neighbors=2, p=1, weights=distance........
# [CV 4/5; 54/64] END leaf_size=30, n_neighbors=2, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 5/5; 54/64] START leaf_size=30, n_neighbors=2, p=1, weights=distance........
# [CV 5/5; 54/64] END leaf_size=30, n_neighbors=2, p=1, weights=distance;, score=0.606 total time=   0.0s
# [CV 1/5; 55/64] START leaf_size=30, n_neighbors=2, p=2, weights=uniform.........
# [CV 1/5; 55/64] END leaf_size=30, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 2/5; 55/64] START leaf_size=30, n_neighbors=2, p=2, weights=uniform.........
# [CV 2/5; 55/64] END leaf_size=30, n_neighbors=2, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 55/64] START leaf_size=30, n_neighbors=2, p=2, weights=uniform.........
# [CV 3/5; 55/64] END leaf_size=30, n_neighbors=2, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 55/64] START leaf_size=30, n_neighbors=2, p=2, weights=uniform.........
# [CV 4/5; 55/64] END leaf_size=30, n_neighbors=2, p=2, weights=uniform;, score=0.551 total time=   0.0s
# [CV 5/5; 55/64] START leaf_size=30, n_neighbors=2, p=2, weights=uniform.........
# [CV 5/5; 55/64] END leaf_size=30, n_neighbors=2, p=2, weights=uniform;, score=0.554 total time=   0.0s
# [CV 1/5; 56/64] START leaf_size=30, n_neighbors=2, p=2, weights=distance........
# [CV 1/5; 56/64] END leaf_size=30, n_neighbors=2, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 2/5; 56/64] START leaf_size=30, n_neighbors=2, p=2, weights=distance........
# [CV 2/5; 56/64] END leaf_size=30, n_neighbors=2, p=2, weights=distance;, score=0.566 total time=   0.0s
# [CV 3/5; 56/64] START leaf_size=30, n_neighbors=2, p=2, weights=distance........
# [CV 3/5; 56/64] END leaf_size=30, n_neighbors=2, p=2, weights=distance;, score=0.587 total time=   0.0s
# [CV 4/5; 56/64] START leaf_size=30, n_neighbors=2, p=2, weights=distance........
# [CV 4/5; 56/64] END leaf_size=30, n_neighbors=2, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 5/5; 56/64] START leaf_size=30, n_neighbors=2, p=2, weights=distance........
# [CV 5/5; 56/64] END leaf_size=30, n_neighbors=2, p=2, weights=distance;, score=0.593 total time=   0.0s
# [CV 1/5; 57/64] START leaf_size=30, n_neighbors=5, p=1, weights=uniform.........
# [CV 1/5; 57/64] END leaf_size=30, n_neighbors=5, p=1, weights=uniform;, score=0.555 total time=   0.0s
# [CV 2/5; 57/64] START leaf_size=30, n_neighbors=5, p=1, weights=uniform.........
# [CV 2/5; 57/64] END leaf_size=30, n_neighbors=5, p=1, weights=uniform;, score=0.546 total time=   0.0s
# [CV 3/5; 57/64] START leaf_size=30, n_neighbors=5, p=1, weights=uniform.........
# [CV 3/5; 57/64] END leaf_size=30, n_neighbors=5, p=1, weights=uniform;, score=0.581 total time=   0.0s
# [CV 4/5; 57/64] START leaf_size=30, n_neighbors=5, p=1, weights=uniform.........
# [CV 4/5; 57/64] END leaf_size=30, n_neighbors=5, p=1, weights=uniform;, score=0.533 total time=   0.0s
# [CV 5/5; 57/64] START leaf_size=30, n_neighbors=5, p=1, weights=uniform.........
# [CV 5/5; 57/64] END leaf_size=30, n_neighbors=5, p=1, weights=uniform;, score=0.576 total time=   0.0s
# [CV 1/5; 58/64] START leaf_size=30, n_neighbors=5, p=1, weights=distance........
# [CV 1/5; 58/64] END leaf_size=30, n_neighbors=5, p=1, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 58/64] START leaf_size=30, n_neighbors=5, p=1, weights=distance........
# [CV 2/5; 58/64] END leaf_size=30, n_neighbors=5, p=1, weights=distance;, score=0.572 total time=   0.0s
# [CV 3/5; 58/64] START leaf_size=30, n_neighbors=5, p=1, weights=distance........
# [CV 3/5; 58/64] END leaf_size=30, n_neighbors=5, p=1, weights=distance;, score=0.605 total time=   0.0s
# [CV 4/5; 58/64] START leaf_size=30, n_neighbors=5, p=1, weights=distance........
# [CV 4/5; 58/64] END leaf_size=30, n_neighbors=5, p=1, weights=distance;, score=0.564 total time=   0.0s
# [CV 5/5; 58/64] START leaf_size=30, n_neighbors=5, p=1, weights=distance........
# [CV 5/5; 58/64] END leaf_size=30, n_neighbors=5, p=1, weights=distance;, score=0.603 total time=   0.0s
# [CV 1/5; 59/64] START leaf_size=30, n_neighbors=5, p=2, weights=uniform.........
# [CV 1/5; 59/64] END leaf_size=30, n_neighbors=5, p=2, weights=uniform;, score=0.543 total time=   0.0s
# [CV 2/5; 59/64] START leaf_size=30, n_neighbors=5, p=2, weights=uniform.........
# [CV 2/5; 59/64] END leaf_size=30, n_neighbors=5, p=2, weights=uniform;, score=0.534 total time=   0.0s
# [CV 3/5; 59/64] START leaf_size=30, n_neighbors=5, p=2, weights=uniform.........
# [CV 3/5; 59/64] END leaf_size=30, n_neighbors=5, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 4/5; 59/64] START leaf_size=30, n_neighbors=5, p=2, weights=uniform.........
# [CV 4/5; 59/64] END leaf_size=30, n_neighbors=5, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 5/5; 59/64] START leaf_size=30, n_neighbors=5, p=2, weights=uniform.........
# [CV 5/5; 59/64] END leaf_size=30, n_neighbors=5, p=2, weights=uniform;, score=0.568 total time=   0.0s
# [CV 1/5; 60/64] START leaf_size=30, n_neighbors=5, p=2, weights=distance........
# [CV 1/5; 60/64] END leaf_size=30, n_neighbors=5, p=2, weights=distance;, score=0.555 total time=   0.0s
# [CV 2/5; 60/64] START leaf_size=30, n_neighbors=5, p=2, weights=distance........
# [CV 2/5; 60/64] END leaf_size=30, n_neighbors=5, p=2, weights=distance;, score=0.554 total time=   0.0s
# [CV 3/5; 60/64] START leaf_size=30, n_neighbors=5, p=2, weights=distance........
# [CV 3/5; 60/64] END leaf_size=30, n_neighbors=5, p=2, weights=distance;, score=0.575 total time=   0.0s
# [CV 4/5; 60/64] START leaf_size=30, n_neighbors=5, p=2, weights=distance........
# [CV 4/5; 60/64] END leaf_size=30, n_neighbors=5, p=2, weights=distance;, score=0.560 total time=   0.0s
# [CV 5/5; 60/64] START leaf_size=30, n_neighbors=5, p=2, weights=distance........
# [CV 5/5; 60/64] END leaf_size=30, n_neighbors=5, p=2, weights=distance;, score=0.582 total time=   0.0s
# [CV 1/5; 61/64] START leaf_size=30, n_neighbors=10, p=1, weights=uniform........
# [CV 1/5; 61/64] END leaf_size=30, n_neighbors=10, p=1, weights=uniform;, score=0.535 total time=   0.0s
# [CV 2/5; 61/64] START leaf_size=30, n_neighbors=10, p=1, weights=uniform........
# [CV 2/5; 61/64] END leaf_size=30, n_neighbors=10, p=1, weights=uniform;, score=0.524 total time=   0.0s
# [CV 3/5; 61/64] START leaf_size=30, n_neighbors=10, p=1, weights=uniform........
# [CV 3/5; 61/64] END leaf_size=30, n_neighbors=10, p=1, weights=uniform;, score=0.548 total time=   0.0s
# [CV 4/5; 61/64] START leaf_size=30, n_neighbors=10, p=1, weights=uniform........
# [CV 4/5; 61/64] END leaf_size=30, n_neighbors=10, p=1, weights=uniform;, score=0.541 total time=   0.0s
# [CV 5/5; 61/64] START leaf_size=30, n_neighbors=10, p=1, weights=uniform........
# [CV 5/5; 61/64] END leaf_size=30, n_neighbors=10, p=1, weights=uniform;, score=0.543 total time=   0.0s
# [CV 1/5; 62/64] START leaf_size=30, n_neighbors=10, p=1, weights=distance.......
# [CV 1/5; 62/64] END leaf_size=30, n_neighbors=10, p=1, weights=distance;, score=0.571 total time=   0.0s
# [CV 2/5; 62/64] START leaf_size=30, n_neighbors=10, p=1, weights=distance.......
# [CV 2/5; 62/64] END leaf_size=30, n_neighbors=10, p=1, weights=distance;, score=0.555 total time=   0.0s
# [CV 3/5; 62/64] START leaf_size=30, n_neighbors=10, p=1, weights=distance.......
# [CV 3/5; 62/64] END leaf_size=30, n_neighbors=10, p=1, weights=distance;, score=0.584 total time=   0.0s
# [CV 4/5; 62/64] START leaf_size=30, n_neighbors=10, p=1, weights=distance.......
# [CV 4/5; 62/64] END leaf_size=30, n_neighbors=10, p=1, weights=distance;, score=0.574 total time=   0.0s
# [CV 5/5; 62/64] START leaf_size=30, n_neighbors=10, p=1, weights=distance.......
# [CV 5/5; 62/64] END leaf_size=30, n_neighbors=10, p=1, weights=distance;, score=0.576 total time=   0.0s
# [CV 1/5; 63/64] START leaf_size=30, n_neighbors=10, p=2, weights=uniform........
# [CV 1/5; 63/64] END leaf_size=30, n_neighbors=10, p=2, weights=uniform;, score=0.538 total time=   0.0s
# [CV 2/5; 63/64] START leaf_size=30, n_neighbors=10, p=2, weights=uniform........
# [CV 2/5; 63/64] END leaf_size=30, n_neighbors=10, p=2, weights=uniform;, score=0.542 total time=   0.0s
# [CV 3/5; 63/64] START leaf_size=30, n_neighbors=10, p=2, weights=uniform........
# [CV 3/5; 63/64] END leaf_size=30, n_neighbors=10, p=2, weights=uniform;, score=0.546 total time=   0.0s
# [CV 4/5; 63/64] START leaf_size=30, n_neighbors=10, p=2, weights=uniform........
# [CV 4/5; 63/64] END leaf_size=30, n_neighbors=10, p=2, weights=uniform;, score=0.535 total time=   0.0s
# [CV 5/5; 63/64] START leaf_size=30, n_neighbors=10, p=2, weights=uniform........
# [CV 5/5; 63/64] END leaf_size=30, n_neighbors=10, p=2, weights=uniform;, score=0.560 total time=   0.0s
# [CV 1/5; 64/64] START leaf_size=30, n_neighbors=10, p=2, weights=distance.......
# [CV 1/5; 64/64] END leaf_size=30, n_neighbors=10, p=2, weights=distance;, score=0.569 total time=   0.0s
# [CV 2/5; 64/64] START leaf_size=30, n_neighbors=10, p=2, weights=distance.......
# [CV 2/5; 64/64] END leaf_size=30, n_neighbors=10, p=2, weights=distance;, score=0.552 total time=   0.0s
# [CV 3/5; 64/64] START leaf_size=30, n_neighbors=10, p=2, weights=distance.......
# [CV 3/5; 64/64] END leaf_size=30, n_neighbors=10, p=2, weights=distance;, score=0.577 total time=   0.0s
# [CV 4/5; 64/64] START leaf_size=30, n_neighbors=10, p=2, weights=distance.......
# [CV 4/5; 64/64] END leaf_size=30, n_neighbors=10, p=2, weights=distance;, score=0.551 total time=   0.0s
# [CV 5/5; 64/64] START leaf_size=30, n_neighbors=10, p=2, weights=distance.......
# [CV 5/5; 64/64] END leaf_size=30, n_neighbors=10, p=2, weights=distance;, score=0.585 total time=   0.0s
# Precisión: 62.2% con {'leaf_size': 5, 'n_neighbors': 1, 'p': 1, 'weights': 'uniform'}

# %% [markdown]
# En este caso, la búsqueda de los mejores parámetros nos permite mejorar el error

# %% [markdown]
# También se le puede aplicar normalización de los datos y PCA antes del KNeighbors para comprobar si el error y el tiempo mejoran

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

scaler = StandardScaler()
pca = PCA()

pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("kv", kv)])

G = {"pca__n_components": [5,10,20,50,100], "kv__n_neighbors": [1,3,5,10]}
GS = GridSearchCV(pipe, G, scoring='accuracy', refit=True, cv=5, verbose=10)
acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START kv__n_neighbors=1, pca__n_components=5.....................
# [CV 1/5; 1/20] END kv__n_neighbors=1, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 2/5; 1/20] START kv__n_neighbors=1, pca__n_components=5.....................
# [CV 2/5; 1/20] END kv__n_neighbors=1, pca__n_components=5;, score=0.520 total time=   0.0s
# [CV 3/5; 1/20] START kv__n_neighbors=1, pca__n_components=5.....................
# [CV 3/5; 1/20] END kv__n_neighbors=1, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 4/5; 1/20] START kv__n_neighbors=1, pca__n_components=5.....................
# [CV 4/5; 1/20] END kv__n_neighbors=1, pca__n_components=5;, score=0.522 total time=   0.0s
# [CV 5/5; 1/20] START kv__n_neighbors=1, pca__n_components=5.....................
# [CV 5/5; 1/20] END kv__n_neighbors=1, pca__n_components=5;, score=0.519 total time=   0.0s
# [CV 1/5; 2/20] START kv__n_neighbors=1, pca__n_components=10....................
# [CV 1/5; 2/20] END kv__n_neighbors=1, pca__n_components=10;, score=0.552 total time=   0.0s
# [CV 2/5; 2/20] START kv__n_neighbors=1, pca__n_components=10....................
# [CV 2/5; 2/20] END kv__n_neighbors=1, pca__n_components=10;, score=0.553 total time=   0.0s
# [CV 3/5; 2/20] START kv__n_neighbors=1, pca__n_components=10....................
# [CV 3/5; 2/20] END kv__n_neighbors=1, pca__n_components=10;, score=0.567 total time=   0.0s
# [CV 4/5; 2/20] START kv__n_neighbors=1, pca__n_components=10....................
# [CV 4/5; 2/20] END kv__n_neighbors=1, pca__n_components=10;, score=0.572 total time=   0.0s
# [CV 5/5; 2/20] START kv__n_neighbors=1, pca__n_components=10....................
# [CV 5/5; 2/20] END kv__n_neighbors=1, pca__n_components=10;, score=0.562 total time=   0.0s
# [CV 1/5; 3/20] START kv__n_neighbors=1, pca__n_components=20....................
# [CV 1/5; 3/20] END kv__n_neighbors=1, pca__n_components=20;, score=0.569 total time=   0.0s
# [CV 2/5; 3/20] START kv__n_neighbors=1, pca__n_components=20....................
# [CV 2/5; 3/20] END kv__n_neighbors=1, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 3/5; 3/20] START kv__n_neighbors=1, pca__n_components=20....................
# [CV 3/5; 3/20] END kv__n_neighbors=1, pca__n_components=20;, score=0.584 total time=   0.0s
# [CV 4/5; 3/20] START kv__n_neighbors=1, pca__n_components=20....................
# [CV 4/5; 3/20] END kv__n_neighbors=1, pca__n_components=20;, score=0.596 total time=   0.0s
# [CV 5/5; 3/20] START kv__n_neighbors=1, pca__n_components=20....................
# [CV 5/5; 3/20] END kv__n_neighbors=1, pca__n_components=20;, score=0.581 total time=   0.0s
# [CV 1/5; 4/20] START kv__n_neighbors=1, pca__n_components=50....................
# [CV 1/5; 4/20] END kv__n_neighbors=1, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/5; 4/20] START kv__n_neighbors=1, pca__n_components=50....................
# [CV 2/5; 4/20] END kv__n_neighbors=1, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/5; 4/20] START kv__n_neighbors=1, pca__n_components=50....................
# [CV 3/5; 4/20] END kv__n_neighbors=1, pca__n_components=50;, score=nan total time=   0.0s
# [CV 4/5; 4/20] START kv__n_neighbors=1, pca__n_components=50....................
# [CV 4/5; 4/20] END kv__n_neighbors=1, pca__n_components=50;, score=nan total time=   0.0s
# [CV 5/5; 4/20] START kv__n_neighbors=1, pca__n_components=50....................
# [CV 5/5; 4/20] END kv__n_neighbors=1, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/5; 5/20] START kv__n_neighbors=1, pca__n_components=100...................
# [CV 1/5; 5/20] END kv__n_neighbors=1, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 5/20] START kv__n_neighbors=1, pca__n_components=100...................
# [CV 2/5; 5/20] END kv__n_neighbors=1, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 5/20] START kv__n_neighbors=1, pca__n_components=100...................
# [CV 3/5; 5/20] END kv__n_neighbors=1, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 5/20] START kv__n_neighbors=1, pca__n_components=100...................
# [CV 4/5; 5/20] END kv__n_neighbors=1, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 5/20] START kv__n_neighbors=1, pca__n_components=100...................
# [CV 5/5; 5/20] END kv__n_neighbors=1, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 6/20] START kv__n_neighbors=3, pca__n_components=5.....................
# [CV 1/5; 6/20] END kv__n_neighbors=3, pca__n_components=5;, score=0.530 total time=   0.0s
# [CV 2/5; 6/20] START kv__n_neighbors=3, pca__n_components=5.....................
# [CV 2/5; 6/20] END kv__n_neighbors=3, pca__n_components=5;, score=0.531 total time=   0.0s
# [CV 3/5; 6/20] START kv__n_neighbors=3, pca__n_components=5.....................
# [CV 3/5; 6/20] END kv__n_neighbors=3, pca__n_components=5;, score=0.532 total time=   0.0s
# [CV 4/5; 6/20] START kv__n_neighbors=3, pca__n_components=5.....................
# [CV 4/5; 6/20] END kv__n_neighbors=3, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 5/5; 6/20] START kv__n_neighbors=3, pca__n_components=5.....................
# [CV 5/5; 6/20] END kv__n_neighbors=3, pca__n_components=5;, score=0.527 total time=   0.0s
# [CV 1/5; 7/20] START kv__n_neighbors=3, pca__n_components=10....................
# [CV 1/5; 7/20] END kv__n_neighbors=3, pca__n_components=10;, score=0.546 total time=   0.0s
# [CV 2/5; 7/20] START kv__n_neighbors=3, pca__n_components=10....................
# [CV 2/5; 7/20] END kv__n_neighbors=3, pca__n_components=10;, score=0.544 total time=   0.0s
# [CV 3/5; 7/20] START kv__n_neighbors=3, pca__n_components=10....................
# [CV 3/5; 7/20] END kv__n_neighbors=3, pca__n_components=10;, score=0.561 total time=   0.0s
# [CV 4/5; 7/20] START kv__n_neighbors=3, pca__n_components=10....................
# [CV 4/5; 7/20] END kv__n_neighbors=3, pca__n_components=10;, score=0.549 total time=   0.1s
# [CV 5/5; 7/20] START kv__n_neighbors=3, pca__n_components=10....................
# [CV 5/5; 7/20] END kv__n_neighbors=3, pca__n_components=10;, score=0.554 total time=   0.0s
# [CV 1/5; 8/20] START kv__n_neighbors=3, pca__n_components=20....................
# [CV 1/5; 8/20] END kv__n_neighbors=3, pca__n_components=20;, score=0.561 total time=   0.0s
# [CV 2/5; 8/20] START kv__n_neighbors=3, pca__n_components=20....................
# [CV 2/5; 8/20] END kv__n_neighbors=3, pca__n_components=20;, score=0.565 total time=   0.0s
# [CV 3/5; 8/20] START kv__n_neighbors=3, pca__n_components=20....................
# [CV 3/5; 8/20] END kv__n_neighbors=3, pca__n_components=20;, score=0.573 total time=   0.0s
# [CV 4/5; 8/20] START kv__n_neighbors=3, pca__n_components=20....................
# [CV 4/5; 8/20] END kv__n_neighbors=3, pca__n_components=20;, score=0.594 total time=   0.0s
# [CV 5/5; 8/20] START kv__n_neighbors=3, pca__n_components=20....................
# [CV 5/5; 8/20] END kv__n_neighbors=3, pca__n_components=20;, score=0.558 total time=   0.0s
# [CV 1/5; 9/20] START kv__n_neighbors=3, pca__n_components=50....................
# [CV 1/5; 9/20] END kv__n_neighbors=3, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/5; 9/20] START kv__n_neighbors=3, pca__n_components=50....................
# [CV 2/5; 9/20] END kv__n_neighbors=3, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/5; 9/20] START kv__n_neighbors=3, pca__n_components=50....................
# [CV 3/5; 9/20] END kv__n_neighbors=3, pca__n_components=50;, score=nan total time=   0.0s
# [CV 4/5; 9/20] START kv__n_neighbors=3, pca__n_components=50....................
# [CV 4/5; 9/20] END kv__n_neighbors=3, pca__n_components=50;, score=nan total time=   0.0s
# [CV 5/5; 9/20] START kv__n_neighbors=3, pca__n_components=50....................
# [CV 5/5; 9/20] END kv__n_neighbors=3, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/5; 10/20] START kv__n_neighbors=3, pca__n_components=100..................
# [CV 1/5; 10/20] END kv__n_neighbors=3, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 10/20] START kv__n_neighbors=3, pca__n_components=100..................
# [CV 2/5; 10/20] END kv__n_neighbors=3, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 10/20] START kv__n_neighbors=3, pca__n_components=100..................
# [CV 3/5; 10/20] END kv__n_neighbors=3, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 10/20] START kv__n_neighbors=3, pca__n_components=100..................
# [CV 4/5; 10/20] END kv__n_neighbors=3, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 10/20] START kv__n_neighbors=3, pca__n_components=100..................
# [CV 5/5; 10/20] END kv__n_neighbors=3, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 11/20] START kv__n_neighbors=5, pca__n_components=5....................
# [CV 1/5; 11/20] END kv__n_neighbors=5, pca__n_components=5;, score=0.542 total time=   0.0s
# [CV 2/5; 11/20] START kv__n_neighbors=5, pca__n_components=5....................
# [CV 2/5; 11/20] END kv__n_neighbors=5, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 3/5; 11/20] START kv__n_neighbors=5, pca__n_components=5....................
# [CV 3/5; 11/20] END kv__n_neighbors=5, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 4/5; 11/20] START kv__n_neighbors=5, pca__n_components=5....................
# [CV 4/5; 11/20] END kv__n_neighbors=5, pca__n_components=5;, score=0.537 total time=   0.0s
# [CV 5/5; 11/20] START kv__n_neighbors=5, pca__n_components=5....................
# [CV 5/5; 11/20] END kv__n_neighbors=5, pca__n_components=5;, score=0.524 total time=   0.0s
# [CV 1/5; 12/20] START kv__n_neighbors=5, pca__n_components=10...................
# [CV 1/5; 12/20] END kv__n_neighbors=5, pca__n_components=10;, score=0.549 total time=   0.0s
# [CV 2/5; 12/20] START kv__n_neighbors=5, pca__n_components=10...................
# [CV 2/5; 12/20] END kv__n_neighbors=5, pca__n_components=10;, score=0.534 total time=   0.1s
# [CV 3/5; 12/20] START kv__n_neighbors=5, pca__n_components=10...................
# [CV 3/5; 12/20] END kv__n_neighbors=5, pca__n_components=10;, score=0.567 total time=   0.0s
# [CV 4/5; 12/20] START kv__n_neighbors=5, pca__n_components=10...................
# [CV 4/5; 12/20] END kv__n_neighbors=5, pca__n_components=10;, score=0.546 total time=   0.1s
# [CV 5/5; 12/20] START kv__n_neighbors=5, pca__n_components=10...................
# [CV 5/5; 12/20] END kv__n_neighbors=5, pca__n_components=10;, score=0.553 total time=   0.0s
# [CV 1/5; 13/20] START kv__n_neighbors=5, pca__n_components=20...................
# [CV 1/5; 13/20] END kv__n_neighbors=5, pca__n_components=20;, score=0.568 total time=   0.0s
# [CV 2/5; 13/20] START kv__n_neighbors=5, pca__n_components=20...................
# [CV 2/5; 13/20] END kv__n_neighbors=5, pca__n_components=20;, score=0.562 total time=   0.0s
# [CV 3/5; 13/20] START kv__n_neighbors=5, pca__n_components=20...................
# [CV 3/5; 13/20] END kv__n_neighbors=5, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 4/5; 13/20] START kv__n_neighbors=5, pca__n_components=20...................
# [CV 4/5; 13/20] END kv__n_neighbors=5, pca__n_components=20;, score=0.576 total time=   0.0s
# [CV 5/5; 13/20] START kv__n_neighbors=5, pca__n_components=20...................
# [CV 5/5; 13/20] END kv__n_neighbors=5, pca__n_components=20;, score=0.557 total time=   0.0s
# [CV 1/5; 14/20] START kv__n_neighbors=5, pca__n_components=50...................
# [CV 1/5; 14/20] END kv__n_neighbors=5, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/5; 14/20] START kv__n_neighbors=5, pca__n_components=50...................
# [CV 2/5; 14/20] END kv__n_neighbors=5, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/5; 14/20] START kv__n_neighbors=5, pca__n_components=50...................
# [CV 3/5; 14/20] END kv__n_neighbors=5, pca__n_components=50;, score=nan total time=   0.0s
# [CV 4/5; 14/20] START kv__n_neighbors=5, pca__n_components=50...................
# [CV 4/5; 14/20] END kv__n_neighbors=5, pca__n_components=50;, score=nan total time=   0.0s
# [CV 5/5; 14/20] START kv__n_neighbors=5, pca__n_components=50...................
# [CV 5/5; 14/20] END kv__n_neighbors=5, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/5; 15/20] START kv__n_neighbors=5, pca__n_components=100..................
# [CV 1/5; 15/20] END kv__n_neighbors=5, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 15/20] START kv__n_neighbors=5, pca__n_components=100..................
# [CV 2/5; 15/20] END kv__n_neighbors=5, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 15/20] START kv__n_neighbors=5, pca__n_components=100..................
# [CV 3/5; 15/20] END kv__n_neighbors=5, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 15/20] START kv__n_neighbors=5, pca__n_components=100..................
# [CV 4/5; 15/20] END kv__n_neighbors=5, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 15/20] START kv__n_neighbors=5, pca__n_components=100..................
# [CV 5/5; 15/20] END kv__n_neighbors=5, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 16/20] START kv__n_neighbors=10, pca__n_components=5...................
# [CV 1/5; 16/20] END kv__n_neighbors=10, pca__n_components=5;, score=0.542 total time=   0.0s
# [CV 2/5; 16/20] START kv__n_neighbors=10, pca__n_components=5...................
# [CV 2/5; 16/20] END kv__n_neighbors=10, pca__n_components=5;, score=0.520 total time=   0.0s
# [CV 3/5; 16/20] START kv__n_neighbors=10, pca__n_components=5...................
# [CV 3/5; 16/20] END kv__n_neighbors=10, pca__n_components=5;, score=0.530 total time=   0.0s
# [CV 4/5; 16/20] START kv__n_neighbors=10, pca__n_components=5...................
# [CV 4/5; 16/20] END kv__n_neighbors=10, pca__n_components=5;, score=0.501 total time=   0.0s
# [CV 5/5; 16/20] START kv__n_neighbors=10, pca__n_components=5...................
# [CV 5/5; 16/20] END kv__n_neighbors=10, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 1/5; 17/20] START kv__n_neighbors=10, pca__n_components=10..................
# [CV 1/5; 17/20] END kv__n_neighbors=10, pca__n_components=10;, score=0.547 total time=   0.0s
# [CV 2/5; 17/20] START kv__n_neighbors=10, pca__n_components=10..................
# [CV 2/5; 17/20] END kv__n_neighbors=10, pca__n_components=10;, score=0.539 total time=   0.1s
# [CV 3/5; 17/20] START kv__n_neighbors=10, pca__n_components=10..................
# [CV 3/5; 17/20] END kv__n_neighbors=10, pca__n_components=10;, score=0.551 total time=   0.1s
# [CV 4/5; 17/20] START kv__n_neighbors=10, pca__n_components=10..................
# [CV 4/5; 17/20] END kv__n_neighbors=10, pca__n_components=10;, score=0.562 total time=   0.1s
# [CV 5/5; 17/20] START kv__n_neighbors=10, pca__n_components=10..................
# [CV 5/5; 17/20] END kv__n_neighbors=10, pca__n_components=10;, score=0.560 total time=   0.0s
# [CV 1/5; 18/20] START kv__n_neighbors=10, pca__n_components=20..................
# [CV 1/5; 18/20] END kv__n_neighbors=10, pca__n_components=20;, score=0.564 total time=   0.0s
# [CV 2/5; 18/20] START kv__n_neighbors=10, pca__n_components=20..................
# [CV 2/5; 18/20] END kv__n_neighbors=10, pca__n_components=20;, score=0.570 total time=   0.0s
# [CV 3/5; 18/20] START kv__n_neighbors=10, pca__n_components=20..................
# [CV 3/5; 18/20] END kv__n_neighbors=10, pca__n_components=20;, score=0.576 total time=   0.0s
# [CV 4/5; 18/20] START kv__n_neighbors=10, pca__n_components=20..................
# [CV 4/5; 18/20] END kv__n_neighbors=10, pca__n_components=20;, score=0.561 total time=   0.0s
# [CV 5/5; 18/20] START kv__n_neighbors=10, pca__n_components=20..................
# [CV 5/5; 18/20] END kv__n_neighbors=10, pca__n_components=20;, score=0.541 total time=   0.0s
# [CV 1/5; 19/20] START kv__n_neighbors=10, pca__n_components=50..................
# [CV 1/5; 19/20] END kv__n_neighbors=10, pca__n_components=50;, score=nan total time=   0.0s
# [CV 2/5; 19/20] START kv__n_neighbors=10, pca__n_components=50..................
# [CV 2/5; 19/20] END kv__n_neighbors=10, pca__n_components=50;, score=nan total time=   0.0s
# [CV 3/5; 19/20] START kv__n_neighbors=10, pca__n_components=50..................
# [CV 3/5; 19/20] END kv__n_neighbors=10, pca__n_components=50;, score=nan total time=   0.0s
# [CV 4/5; 19/20] START kv__n_neighbors=10, pca__n_components=50..................
# [CV 4/5; 19/20] END kv__n_neighbors=10, pca__n_components=50;, score=nan total time=   0.0s
# [CV 5/5; 19/20] START kv__n_neighbors=10, pca__n_components=50..................
# [CV 5/5; 19/20] END kv__n_neighbors=10, pca__n_components=50;, score=nan total time=   0.0s
# [CV 1/5; 20/20] START kv__n_neighbors=10, pca__n_components=100.................
# [CV 1/5; 20/20] END kv__n_neighbors=10, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 20/20] START kv__n_neighbors=10, pca__n_components=100.................
# [CV 2/5; 20/20] END kv__n_neighbors=10, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 20/20] START kv__n_neighbors=10, pca__n_components=100.................
# [CV 3/5; 20/20] END kv__n_neighbors=10, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 20/20] START kv__n_neighbors=10, pca__n_components=100.................
# [CV 4/5; 20/20] END kv__n_neighbors=10, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 20/20] START kv__n_neighbors=10, pca__n_components=100.................
# [CV 5/5; 20/20] END kv__n_neighbors=10, pca__n_components=100;, score=nan total time=   0.0s
# Precisión: 60.4% con {'kv__n_neighbors': 1, 'pca__n_components': 20}

# %% [markdown]
# En este caso la precisión empeora si se usa PCA con menos parámetros

# %% [markdown]
# Probamos con los mismos parámetros que el anterior

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline

scaler = StandardScaler()
pca = PCA()

pipe = Pipeline(steps=[("scaler", scaler), ("pca", pca), ("kv", kv)])

G = {"pca__n_components": [5,20,100], "kv__n_neighbors": [1,3,5], 'kv__weights':['uniform', 'distance'], 'kv__leaf_size': [5,10,20], 'kv__p': [1,2]}
GS = GridSearchCV(pipe, G, scoring='accuracy', refit=True, cv=5, verbose=10)
acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 108 candidates, totalling 540 fits
# [CV 1/5; 1/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 1/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.527 total time=   0.0s
# [CV 2/5; 1/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 1/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 3/5; 1/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 1/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.523 total time=   0.0s
# [CV 4/5; 1/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 1/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.519 total time=   0.0s
# [CV 5/5; 1/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 1/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 1/5; 2/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 2/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.573 total time=   0.0s
# [CV 2/5; 2/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 2/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.553 total time=   0.0s
# [CV 3/5; 2/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 2/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.594 total time=   0.0s
# [CV 4/5; 2/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 2/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.603 total time=   0.0s
# [CV 5/5; 2/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 2/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.591 total time=   0.0s
# [CV 1/5; 3/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 3/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 3/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 3/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 3/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 3/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 3/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 3/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 3/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 3/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 4/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 1/5; 4/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.523 total time=   0.0s
# [CV 2/5; 4/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 2/5; 4/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.525 total time=   0.0s
# [CV 3/5; 4/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 3/5; 4/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.526 total time=   0.0s
# [CV 4/5; 4/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 4/5; 4/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.516 total time=   0.0s
# [CV 5/5; 4/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 5/5; 4/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.530 total time=   0.0s
# [CV 1/5; 5/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 1/5; 5/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.573 total time=   0.0s
# [CV 2/5; 5/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 2/5; 5/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.553 total time=   0.0s
# [CV 3/5; 5/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 3/5; 5/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.594 total time=   0.0s
# [CV 4/5; 5/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 4/5; 5/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.603 total time=   0.0s
# [CV 5/5; 5/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 5/5; 5/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.591 total time=   0.0s
# [CV 1/5; 6/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 1/5; 6/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 6/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 2/5; 6/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 6/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 3/5; 6/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 6/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 4/5; 6/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 6/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 5/5; 6/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 7/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 7/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 2/5; 7/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 7/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.519 total time=   0.0s
# [CV 3/5; 7/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 7/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 4/5; 7/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 7/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.522 total time=   0.0s
# [CV 5/5; 7/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 7/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.519 total time=   0.0s
# [CV 1/5; 8/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 8/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.569 total time=   0.0s
# [CV 2/5; 8/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 8/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 3/5; 8/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 8/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.584 total time=   0.0s
# [CV 4/5; 8/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 8/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.596 total time=   0.0s
# [CV 5/5; 8/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 8/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.581 total time=   0.0s
# [CV 1/5; 9/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 9/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 9/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 9/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 9/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 9/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 9/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 9/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 9/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 9/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 10/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 1/5; 10/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.540 total time=   0.0s
# [CV 2/5; 10/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 2/5; 10/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 3/5; 10/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 3/5; 10/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 4/5; 10/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 4/5; 10/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.522 total time=   0.0s
# [CV 5/5; 10/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 5/5; 10/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.517 total time=   0.0s
# [CV 1/5; 11/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 1/5; 11/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.569 total time=   0.0s
# [CV 2/5; 11/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 2/5; 11/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 3/5; 11/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 3/5; 11/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.584 total time=   0.0s
# [CV 4/5; 11/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 4/5; 11/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.596 total time=   0.0s
# [CV 5/5; 11/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 5/5; 11/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.581 total time=   0.0s
# [CV 1/5; 12/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 1/5; 12/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 12/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 2/5; 12/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 12/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 3/5; 12/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 12/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 4/5; 12/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 12/108] START kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 5/5; 12/108] END kv__leaf_size=5, kv__n_neighbors=1, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 13/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 13/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 2/5; 13/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 13/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.523 total time=   0.0s
# [CV 3/5; 13/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 13/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 4/5; 13/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 13/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 5/5; 13/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 13/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 1/5; 14/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 14/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.565 total time=   0.0s
# [CV 2/5; 14/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 14/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.545 total time=   0.0s
# [CV 3/5; 14/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 14/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.588 total time=   0.0s
# [CV 4/5; 14/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 14/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.595 total time=   0.0s
# [CV 5/5; 14/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 14/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.570 total time=   0.0s
# [CV 1/5; 15/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 15/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 15/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 15/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 15/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 15/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 15/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 15/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 15/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 15/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 16/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 1/5; 16/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 2/5; 16/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 2/5; 16/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.519 total time=   0.0s
# [CV 3/5; 16/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 3/5; 16/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 4/5; 16/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 4/5; 16/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.541 total time=   0.0s
# [CV 5/5; 16/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 5/5; 16/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 1/5; 17/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 1/5; 17/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.567 total time=   0.0s
# [CV 2/5; 17/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 2/5; 17/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.550 total time=   0.0s
# [CV 3/5; 17/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 3/5; 17/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.591 total time=   0.0s
# [CV 4/5; 17/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 4/5; 17/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.599 total time=   0.0s
# [CV 5/5; 17/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 5/5; 17/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.572 total time=   0.0s
# [CV 1/5; 18/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 1/5; 18/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 18/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 2/5; 18/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 18/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 3/5; 18/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 18/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 4/5; 18/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 18/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 5/5; 18/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 19/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 19/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.531 total time=   0.0s
# [CV 2/5; 19/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 19/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 3/5; 19/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 19/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 4/5; 19/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 19/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.543 total time=   0.0s
# [CV 5/5; 19/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 19/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.530 total time=   0.0s
# [CV 1/5; 20/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 20/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.561 total time=   0.0s
# [CV 2/5; 20/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 20/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.565 total time=   0.0s
# [CV 3/5; 20/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 20/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.573 total time=   0.0s
# [CV 4/5; 20/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 20/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.594 total time=   0.0s
# [CV 5/5; 20/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 20/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.558 total time=   0.0s
# [CV 1/5; 21/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 21/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 21/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 21/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 21/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 21/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 21/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 21/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 21/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 21/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 22/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 1/5; 22/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.531 total time=   0.0s
# [CV 2/5; 22/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 2/5; 22/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.532 total time=   0.0s
# [CV 3/5; 22/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 3/5; 22/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.531 total time=   0.0s
# [CV 4/5; 22/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 4/5; 22/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.541 total time=   0.0s
# [CV 5/5; 22/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 5/5; 22/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.530 total time=   0.0s
# [CV 1/5; 23/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 1/5; 23/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.564 total time=   0.0s
# [CV 2/5; 23/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 2/5; 23/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.569 total time=   0.0s
# [CV 3/5; 23/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 3/5; 23/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.577 total time=   0.0s
# [CV 4/5; 23/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 4/5; 23/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.596 total time=   0.0s
# [CV 5/5; 23/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 5/5; 23/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.564 total time=   0.0s
# [CV 1/5; 24/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 1/5; 24/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 24/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 2/5; 24/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 24/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 3/5; 24/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 24/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 4/5; 24/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 24/108] START kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 5/5; 24/108] END kv__leaf_size=5, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 25/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 25/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.534 total time=   0.0s
# [CV 2/5; 25/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 25/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.520 total time=   0.0s
# [CV 3/5; 25/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 25/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.543 total time=   0.0s
# [CV 4/5; 25/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 25/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.537 total time=   0.0s
# [CV 5/5; 25/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 25/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 1/5; 26/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 26/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 2/5; 26/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 26/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.558 total time=   0.0s
# [CV 3/5; 26/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 26/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.585 total time=   0.0s
# [CV 4/5; 26/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 26/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.590 total time=   0.0s
# [CV 5/5; 26/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 26/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.567 total time=   0.0s
# [CV 1/5; 27/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 27/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 27/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 27/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 27/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 27/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 27/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 27/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 27/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 27/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 28/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 1/5; 28/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.532 total time=   0.0s
# [CV 2/5; 28/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 2/5; 28/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.518 total time=   0.0s
# [CV 3/5; 28/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 3/5; 28/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.540 total time=   0.0s
# [CV 4/5; 28/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 4/5; 28/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 5/5; 28/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 5/5; 28/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.534 total time=   0.0s
# [CV 1/5; 29/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 1/5; 29/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.564 total time=   0.0s
# [CV 2/5; 29/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 2/5; 29/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.562 total time=   0.0s
# [CV 3/5; 29/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 3/5; 29/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.589 total time=   0.0s
# [CV 4/5; 29/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 4/5; 29/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.597 total time=   0.0s
# [CV 5/5; 29/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 5/5; 29/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 1/5; 30/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 1/5; 30/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 30/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 2/5; 30/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 30/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 3/5; 30/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 30/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 4/5; 30/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 30/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 5/5; 30/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 31/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 31/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.540 total time=   0.0s
# [CV 2/5; 31/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 31/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 3/5; 31/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 31/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 4/5; 31/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 31/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 5/5; 31/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 31/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.523 total time=   0.0s
# [CV 1/5; 32/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 32/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.568 total time=   0.0s
# [CV 2/5; 32/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 32/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.562 total time=   0.0s
# [CV 3/5; 32/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 32/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 4/5; 32/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 32/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.576 total time=   0.0s
# [CV 5/5; 32/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 32/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.557 total time=   0.0s
# [CV 1/5; 33/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 33/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 33/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 33/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 33/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 33/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 33/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 33/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 33/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 33/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 34/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 1/5; 34/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 2/5; 34/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 2/5; 34/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.538 total time=   0.0s
# [CV 3/5; 34/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 3/5; 34/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.532 total time=   0.0s
# [CV 4/5; 34/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 4/5; 34/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 5/5; 34/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 5/5; 34/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.527 total time=   0.0s
# [CV 1/5; 35/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 1/5; 35/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 2/5; 35/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 2/5; 35/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.567 total time=   0.0s
# [CV 3/5; 35/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 3/5; 35/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.577 total time=   0.0s
# [CV 4/5; 35/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 4/5; 35/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.581 total time=   0.0s
# [CV 5/5; 35/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 5/5; 35/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 1/5; 36/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 1/5; 36/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 36/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 2/5; 36/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 36/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 3/5; 36/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 36/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 4/5; 36/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 36/108] START kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 5/5; 36/108] END kv__leaf_size=5, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 37/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 37/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 2/5; 37/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 37/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.525 total time=   0.0s
# [CV 3/5; 37/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 37/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.527 total time=   0.0s
# [CV 4/5; 37/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 37/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.517 total time=   0.0s
# [CV 5/5; 37/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 37/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.527 total time=   0.0s
# [CV 1/5; 38/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 38/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.573 total time=   0.0s
# [CV 2/5; 38/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 38/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.553 total time=   0.0s
# [CV 3/5; 38/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 38/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.594 total time=   0.0s
# [CV 4/5; 38/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 38/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.603 total time=   0.0s
# [CV 5/5; 38/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 38/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.591 total time=   0.0s
# [CV 1/5; 39/108] START kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 39/108] END kv__leaf_size=10, kv__n_neighbors=1, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# ...
# [CV 4/5; 96/108] START kv__leaf_size=20, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 4/5; 96/108] END kv__leaf_size=20, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 96/108] START kv__leaf_size=20, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 5/5; 96/108] END kv__leaf_size=20, kv__n_neighbors=3, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 97/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 97/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.529 total time=   0.0s
# [CV 2/5; 97/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 97/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.521 total time=   0.0s
# [CV 3/5; 97/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 97/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.534 total time=   0.0s
# [CV 4/5; 97/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 97/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 5/5; 97/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 97/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 1/5; 98/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 98/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 2/5; 98/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 98/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.558 total time=   0.0s
# [CV 3/5; 98/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 98/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.585 total time=   0.0s
# [CV 4/5; 98/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 98/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.590 total time=   0.0s
# [CV 5/5; 98/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 98/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=20;, score=0.567 total time=   0.0s
# [CV 1/5; 99/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 99/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 99/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 99/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 99/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 99/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 99/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 99/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 99/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 99/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 100/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 1/5; 100/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.529 total time=   0.0s
# [CV 2/5; 100/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 2/5; 100/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.515 total time=   0.0s
# [CV 3/5; 100/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 3/5; 100/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 4/5; 100/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 4/5; 100/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.535 total time=   0.0s
# [CV 5/5; 100/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5
# [CV 5/5; 100/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=5;, score=0.529 total time=   0.0s
# [CV 1/5; 101/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 1/5; 101/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.564 total time=   0.0s
# [CV 2/5; 101/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 2/5; 101/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.562 total time=   0.0s
# [CV 3/5; 101/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 3/5; 101/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.589 total time=   0.0s
# [CV 4/5; 101/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 4/5; 101/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.597 total time=   0.0s
# [CV 5/5; 101/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20
# [CV 5/5; 101/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 1/5; 102/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 1/5; 102/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 102/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 2/5; 102/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 102/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 3/5; 102/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 102/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 4/5; 102/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 102/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100
# [CV 5/5; 102/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=1, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 103/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 1/5; 103/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.541 total time=   0.0s
# [CV 2/5; 103/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 2/5; 103/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.539 total time=   0.0s
# [CV 3/5; 103/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 3/5; 103/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 4/5; 103/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 4/5; 103/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 5/5; 103/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5
# [CV 5/5; 103/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=5;, score=0.523 total time=   0.0s
# [CV 1/5; 104/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 1/5; 104/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.568 total time=   0.0s
# [CV 2/5; 104/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 2/5; 104/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.562 total time=   0.0s
# [CV 3/5; 104/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 3/5; 104/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 4/5; 104/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 4/5; 104/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.576 total time=   0.0s
# [CV 5/5; 104/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20
# [CV 5/5; 104/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=20;, score=0.557 total time=   0.0s
# [CV 1/5; 105/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 1/5; 105/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 105/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 2/5; 105/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 105/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 3/5; 105/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 105/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 4/5; 105/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 105/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100
# [CV 5/5; 105/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=uniform, pca__n_components=100;, score=nan total time=   0.0s
# [CV 1/5; 106/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 1/5; 106/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.531 total time=   0.0s
# [CV 2/5; 106/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 2/5; 106/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.536 total time=   0.0s
# [CV 3/5; 106/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 3/5; 106/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.528 total time=   0.0s
# [CV 4/5; 106/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 4/5; 106/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.533 total time=   0.0s
# [CV 5/5; 106/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5
# [CV 5/5; 106/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=5;, score=0.524 total time=   0.0s
# [CV 1/5; 107/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 1/5; 107/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.571 total time=   0.0s
# [CV 2/5; 107/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 2/5; 107/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.567 total time=   0.0s
# [CV 3/5; 107/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 3/5; 107/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.577 total time=   0.0s
# [CV 4/5; 107/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 4/5; 107/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.581 total time=   0.0s
# [CV 5/5; 107/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20
# [CV 5/5; 107/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=20;, score=0.563 total time=   0.0s
# [CV 1/5; 108/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 1/5; 108/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 2/5; 108/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 2/5; 108/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 3/5; 108/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 3/5; 108/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 4/5; 108/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 4/5; 108/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# [CV 5/5; 108/108] START kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100
# [CV 5/5; 108/108] END kv__leaf_size=20, kv__n_neighbors=5, kv__p=2, kv__weights=distance, pca__n_components=100;, score=nan total time=   0.0s
# Precisión: 60.3% con {'kv__leaf_size': 5, 'kv__n_neighbors': 1, 'kv__p': 1, 'kv__weights': 'uniform', 'pca__n_components': 20}

# %% [markdown]
# Pero la precisión tampoco mejora
